# %%
import requests
import pandas as pd

import numpy as np

# %% [markdown]
# ## Extract

# %%
# url for api

url = 'https://randomuser.me/api/'

num_of_users = '?results=100' # we can select the number of user to pull

url = url + num_of_users

print(url)
# Out:
# https://randomuser.me/api/?results=100

# %% [markdown]
# there are two major types of method in api: get and post

# %%
# hitting the api and storing the response

response = requests.get(url)

# %%
# if response is 200 then success, if 500 then internal error, 404 means not found
response
# Out:
# <Response [200]>

# %%
if response.status_code == 200: # to check if we are getting results
    data = response.json() # storing the result

# %%
data
# Out:
# {'results': [{'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Mattie', 'last': 'Reed'},
#    'location': {'street': {'number': 1846, 'name': 'Blossom Hill Rd'},
#     'city': 'Rockhampton',
#     'state': 'New South Wales',
#     'country': 'Australia',
#     'postcode': 5310,
#     'coordinates': {'latitude': '-85.0727', 'longitude': '156.8412'},
#     'timezone': {'offset': '+10:00',
#      'description': 'Eastern Australia, Guam, Vladivostok'}},
#    'email': 'mattie.reed@example.com',
#    'login': {'uuid': 'ab7f20b3-83f8-409e-a184-08957eca3b2e',
#     'username': 'crazybear594',
#     'password': 'macaroni',
#     'salt': 'n9GcL4Qf',
#     'md5': 'f92f78c00ab6275cb2be958e9adfce52',
#     'sha1': '401f40d8c9814e50cea1ab5dae1b6678b9f64a9d',
#     'sha256': 'f277ba6b65ef27b4492a44e33ef5402ad78489a9825e8e345b2ccfea722f4119'},
#    'dob': {'date': '1976-12-16T04:08:53.186Z', 'age': 47},
#    'registered': {'date': '2008-08-04T03:25:11.063Z', 'age': 16},
#    'phone': '09-7627-1907',
#    'cell': '0453-553-546',
#    'id': {'name': 'TFN', 'value': '082931467'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/45.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/45.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/45.jpg'},
#    'nat': 'AU'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Vanity', 'last': 'De Hoogh'},
#    'location': {'street': {'number': 1918, 'name': "Achter 'T Ven"},
#     'city': 'Walem',
#     'state': 'Zuid-Holland',
#     'country': 'Netherlands',
#     'postcode': '6680 WY',
#     'coordinates': {'latitude': '-77.4466', 'longitude': '100.5976'},
#     'timezone': {'offset': '+11:00',
#      'description': 'Magadan, Solomon Islands, New Caledonia'}},
#    'email': 'vanity.dehoogh@example.com',
#    'login': {'uuid': '8599587a-0d3f-4627-9b8a-8e29f30ef083',
#     'username': 'silvercat349',
#     'password': 'qwerty123',
#     'salt': 'Fnp2lnkS',
#     'md5': '50bcc3c0ab466cec10eb33d85b9393c8',
#     'sha1': '41cc7486fd6a9a812a9d9654fbad5c48d1a6ff10',
#     'sha256': '200133434f9e24a858ffefae72bb70256f16568d2c1b70ece33ee558c336e49b'},
#    'dob': {'date': '1964-11-15T21:50:21.259Z', 'age': 60},
#    'registered': {'date': '2004-07-17T08:48:53.024Z', 'age': 20},
#    'phone': '(0623) 482904',
#    'cell': '(06) 25483191',
#    'id': {'name': 'BSN', 'value': '08685444'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/43.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/43.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/43.jpg'},
#    'nat': 'NL'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Mercedes', 'last': 'Cortes'},
#    'location': {'street': {'number': 416, 'name': 'Calle de Ferraz'},
#     'city': 'Orihuela',
#     'state': 'Canarias',
#     'country': 'Spain',
#     'postcode': 98943,
#     'coordinates': {'latitude': '-44.9633', 'longitude': '130.3126'},
#     'timezone': {'offset': '+6:00', 'description': 'Almaty, Dhaka, Colombo'}},
#    'email': 'mercedes.cortes@example.com',
#    'login': {'uuid': '332bbb24-5171-46ac-a913-5b456d4e16f3',
#     'username': 'purpleswan117',
#     'password': '4321',
#     'salt': '41DrRtFd',
#     'md5': 'a4d8716cc33f301938eae271c2b08b5f',
#     'sha1': '9fef11eb1792e3f9f95604ac2e053067b0887820',
#     'sha256': 'c902f3f48da36ecb1e7a4f7d7a5ed412df0cc186b36076562b95add09b517308'},
#    'dob': {'date': '1982-07-02T08:05:59.951Z', 'age': 42},
#    'registered': {'date': '2012-05-08T23:27:00.107Z', 'age': 12},
#    'phone': '919-456-598',
#    'cell': '681-289-584',
#    'id': {'name': 'DNI', 'value': '36233518-X'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/26.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/26.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/26.jpg'},
#    'nat': 'ES'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Irma', 'last': 'Luna'},
#    'location': {'street': {'number': 6709, 'name': 'Avenida Chihuahua'},
#     'city': 'Playa Azul',
#     'state': 'Nuevo Leon',
#     'country': 'Mexico',
#     'postcode': 12661,
#     'coordinates': {'latitude': '3.5521', 'longitude': '-31.7700'},
#     'timezone': {'offset': '+5:45', 'description': 'Kathmandu'}},
#    'email': 'irma.luna@example.com',
#    'login': {'uuid': 'd62e21e9-d876-46aa-90df-4ea26c0792fe',
#     'username': 'happymeercat136',
#     'password': 'pass1',
#     'salt': 'vWXGSnEF',
#     'md5': '4a3399211557883849db6199ed84ba24',
#     'sha1': '1f49cf91adb64e9f9d735ea5725bb4902492634f',
#     'sha256': 'adb76d367dad687be9d1a64d3aafff2419e5a1499e272c06226cd706a855929f'},
#    'dob': {'date': '1998-01-16T21:43:54.908Z', 'age': 26},
#    'registered': {'date': '2007-06-27T22:37:54.621Z', 'age': 17},
#    'phone': '(648) 305 5322',
#    'cell': '(697) 740 1596',
#    'id': {'name': 'NSS', 'value': '56 04 36 3992 5'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/96.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/96.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/96.jpg'},
#    'nat': 'MX'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Seb', 'last': 'Bloemen'},
#    'location': {'street': {'number': 401, 'name': 'Brillstraat'},
#     'city': 'Ugchelen',
#     'state': 'Gelderland',
#     'country': 'Netherlands',
#     'postcode': '7978 FP',
#     'coordinates': {'latitude': '61.2446', 'longitude': '-5.9097'},
#     'timezone': {'offset': '+4:00',
#      'description': 'Abu Dhabi, Muscat, Baku, Tbilisi'}},
#    'email': 'seb.bloemen@example.com',
#    'login': {'uuid': '4b48009d-0a84-42f6-999e-dd23ef9d75a3',
#     'username': 'tinyostrich507',
#     'password': 'video1',
#     'salt': '73aDmNBf',
#     'md5': 'bb554abd8ada5603036796f5fe7b06ab',
#     'sha1': '486b7b7c69854516c171ca18f4b7e7a37ceb8e00',
#     'sha256': 'cc6f756638a9f2f0ef381c047a84cd048f9362535313bec6fa6eff2420f7e984'},
#    'dob': {'date': '1958-11-24T12:54:51.346Z', 'age': 66},
#    'registered': {'date': '2012-12-25T12:10:31.637Z', 'age': 11},
#    'phone': '(0055) 920201',
#    'cell': '(06) 09911515',
#    'id': {'name': 'BSN', 'value': '55119784'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/16.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/16.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/16.jpg'},
#    'nat': 'NL'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Iiris', 'last': 'Marttila'},
#    'location': {'street': {'number': 1957, 'name': 'Hämeenkatu'},
#     'city': 'Ristijärvi',
#     'state': 'Päijät-Häme',
#     'country': 'Finland',
#     'postcode': 93099,
#     'coordinates': {'latitude': '-19.8741', 'longitude': '-67.3496'},
#     'timezone': {'offset': '-10:00', 'description': 'Hawaii'}},
#    'email': 'iiris.marttila@example.com',
#    'login': {'uuid': '82ee9b78-7ca1-4990-9cc8-b378a690f4f7',
#     'username': 'bluedog832',
#     'password': 'filthy',
#     'salt': '6rt40wQm',
#     'md5': '8f71148c34a52f7d59736d81e1a34483',
#     'sha1': 'a2bb13eab922923a2c56f9f45f04f6f442b48a50',
#     'sha256': 'dac248c524b3f8a0a9bcf339d9fa721e19086f2fa7ac5feb27f9b9b843d59111'},
#    'dob': {'date': '1995-02-19T06:40:45.582Z', 'age': 29},
#    'registered': {'date': '2020-08-23T17:05:30.063Z', 'age': 4},
#    'phone': '02-228-836',
#    'cell': '041-731-65-07',
#    'id': {'name': 'HETU', 'value': 'NaNNA944undefined'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/1.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/1.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/1.jpg'},
#    'nat': 'FI'},
#   {'gender': 'female',
#    'name': {'title': 'Ms', 'first': 'Corinda', 'last': 'Van Langen'},
#    'location': {'street': {'number': 1033, 'name': 'Burgemeester Beckersweg'},
#     'city': 'Eesterga',
#     'state': 'Utrecht',
#     'country': 'Netherlands',
#     'postcode': '0186 AU',
#     'coordinates': {'latitude': '71.2965', 'longitude': '-67.6218'},
#     'timezone': {'offset': '+3:30', 'description': 'Tehran'}},
#    'email': 'corinda.vanlangen@example.com',
#    'login': {'uuid': '089644fc-b701-48fa-8906-494ff38a5d09',
#     'username': 'ticklishgorilla789',
#     'password': 'corinne',
#     'salt': 'Yc8FztHf',
#     'md5': '742108dd46a63c0459856cc7f7efb84f',
#     'sha1': '88dfceed92bc74dcd050d28b0bb7d57fee784719',
#     'sha256': '6d0415b8b0613748af62c4c06de180767daf7cf97c21e907e5bb707eff2813a7'},
#    'dob': {'date': '1945-10-27T21:40:46.578Z', 'age': 79},
#    'registered': {'date': '2002-11-16T05:51:33.939Z', 'age': 22},
#    'phone': '(076) 8966742',
#    'cell': '(06) 34011839',
#    'id': {'name': 'BSN', 'value': '17265620'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/21.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/21.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/21.jpg'},
#    'nat': 'NL'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Alex', 'last': 'Giménez'},
#    'location': {'street': {'number': 9103,
#      'name': 'Calle de Alberto Aguilera'},
#     'city': 'Sevilla',
#     'state': 'Islas Baleares',
#     'country': 'Spain',
#     'postcode': 93800,
#     'coordinates': {'latitude': '-82.7815', 'longitude': '-102.3392'},
#     'timezone': {'offset': '-11:00', 'description': 'Midway Island, Samoa'}},
#    'email': 'alex.gimenez@example.com',
#    'login': {'uuid': 'd53fd073-a71f-4ea7-8825-9a57897b088f',
#     'username': 'orangeduck410',
#     'password': 'berlin',
#     'salt': '022jkCWy',
#     'md5': 'f857dc032208cbb3b78c0432970de40b',
#     'sha1': '89ab8c5b7db8952a4b8e1334793901272779a9aa',
#     'sha256': 'f78b90fa5679d9db0e7554d2dfebf49747cce3e3a1ad0192b7f8a53e52c8d2bc'},
#    'dob': {'date': '1953-03-09T13:03:27.675Z', 'age': 71},
#    'registered': {'date': '2013-05-06T19:40:20.589Z', 'age': 11},
#    'phone': '949-816-600',
#    'cell': '678-815-693',
#    'id': {'name': 'DNI', 'value': '85329584-V'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/54.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/54.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/54.jpg'},
#    'nat': 'ES'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Gül', 'last': 'Erez'},
#    'location': {'street': {'number': 24, 'name': 'Vatan Cd'},
#     'city': 'Isparta',
#     'state': 'Yalova',
#     'country': 'Turkey',
#     'postcode': 75130,
#     'coordinates': {'latitude': '-48.1753', 'longitude': '-146.8055'},
#     'timezone': {'offset': '+10:00',
#      'description': 'Eastern Australia, Guam, Vladivostok'}},
#    'email': 'gul.erez@example.com',
#    'login': {'uuid': '412d0fe1-1818-4882-9ebd-7cfce395b591',
#     'username': 'tinyfrog782',
#     'password': 'chance',
#     'salt': 'swPrsQ07',
#     'md5': '33e40a3c234018df11e4c3b80dec993d',
#     'sha1': 'bfc7e9e2468c5fe68e4a77f40ed8ff445928e7a6',
#     'sha256': '0499db4b257dbf200c36bc5a5af9508b2e5cfe35c92e07e844353714991175d0'},
#    'dob': {'date': '1991-08-19T11:11:37.517Z', 'age': 33},
#    'registered': {'date': '2006-02-16T00:20:24.161Z', 'age': 18},
#    'phone': '(910)-276-6848',
#    'cell': '(204)-417-3209',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/13.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/13.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/13.jpg'},
#    'nat': 'TR'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Caroline', 'last': 'Mortensen'},
#    'location': {'street': {'number': 4386, 'name': 'Villavej'},
#     'city': 'Hornbæk',
#     'state': 'Midtjylland',
#     'country': 'Denmark',
#     'postcode': 31391,
#     'coordinates': {'latitude': '-77.5779', 'longitude': '-109.5508'},
#     'timezone': {'offset': '+3:00',
#      'description': 'Baghdad, Riyadh, Moscow, St. Petersburg'}},
#    'email': 'caroline.mortensen@example.com',
#    'login': {'uuid': '3b9ee44e-f5b3-4532-9ee0-143de592c52a',
#     'username': 'smallzebra632',
#     'password': 'captain',
#     'salt': 'obw68GWT',
#     'md5': '6bbf18d717e8484e92d099be475a5c69',
#     'sha1': '1b10849cdb2ba8a84e68e52d190949e7cb1b103d',
#     'sha256': 'ead2b64d4c1d1ab38eb18916ea7b9e01976ddad8d690969e156dd0b8fa6e7000'},
#    'dob': {'date': '1952-12-14T07:37:35.281Z', 'age': 71},
#    'registered': {'date': '2008-10-02T23:18:10.057Z', 'age': 16},
#    'phone': '77612464',
#    'cell': '14481011',
#    'id': {'name': 'CPR', 'value': '141252-1667'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/91.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/91.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/91.jpg'},
#    'nat': 'DK'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Gordiy', 'last': 'Katrich'},
#    'location': {'street': {'number': 9273, 'name': 'Yacika'},
#     'city': 'Shepetivka',
#     'state': 'Zakarpatska',
#     'country': 'Ukraine',
#     'postcode': 75756,
#     'coordinates': {'latitude': '14.3226', 'longitude': '-158.2118'},
#     'timezone': {'offset': '+2:00',
#      'description': 'Kaliningrad, South Africa'}},
#    'email': 'gordiy.katrich@example.com',
#    'login': {'uuid': 'cf69bb2d-e913-43c8-90f8-64814d6c003c',
#     'username': 'bluebutterfly334',
#     'password': 'gotmilk',
#     'salt': 'RtTPFNHM',
#     'md5': '33edde6545c3283339c8f0f7a9161484',
#     'sha1': '59fd11a17145ac9086cdc4765ad1d494b08ac687',
#     'sha256': 'c0e4ae4cd61f8d639bf39acfda18682514964ea2a12d6a54fd403956a0bfbf80'},
#    'dob': {'date': '1977-04-13T06:21:14.229Z', 'age': 47},
#    'registered': {'date': '2008-07-22T11:29:11.237Z', 'age': 16},
#    'phone': '(097) V61-9330',
#    'cell': '(096) G96-3432',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/52.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/52.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/52.jpg'},
#    'nat': 'UA'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Ege', 'last': 'Çetiner'},
#    'location': {'street': {'number': 8894, 'name': 'Tunalı Hilmi Cd'},
#     'city': 'Edirne',
#     'state': 'Antalya',
#     'country': 'Turkey',
#     'postcode': 34168,
#     'coordinates': {'latitude': '29.4641', 'longitude': '118.1336'},
#     'timezone': {'offset': '-8:00',
#      'description': 'Pacific Time (US & Canada)'}},
#    'email': 'ege.cetiner@example.com',
#    'login': {'uuid': 'fa9c7400-88af-4f24-8571-22d5e3c3a8a4',
#     'username': 'sadtiger608',
#     'password': 'goodbye',
#     'salt': 'qye3Xk6R',
#     'md5': '8182cd697e38f5da5ddcb8dcbab7a5db',
#     'sha1': '9df65ee498a6b3ebd119705d63bb3c98f01ad304',
#     'sha256': 'bf3be0cf855ade580a885105a705c44f488da8ea5a860f376bf6817e0b4564db'},
#    'dob': {'date': '1995-05-19T06:58:20.710Z', 'age': 29},
#    'registered': {'date': '2008-04-10T15:55:14.125Z', 'age': 16},
#    'phone': '(028)-850-4449',
#    'cell': '(044)-580-0951',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/17.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/17.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/17.jpg'},
#    'nat': 'TR'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Corinne', 'last': 'Bechtold'},
#    'location': {'street': {'number': 8371, 'name': 'Marktplatz'},
#     'city': 'Wunstorf',
#     'state': 'Bremen',
#     'country': 'Germany',
#     'postcode': 77536,
#     'coordinates': {'latitude': '-89.1432', 'longitude': '-162.3880'},
#     'timezone': {'offset': '+8:00',
#      'description': 'Beijing, Perth, Singapore, Hong Kong'}},
#    'email': 'corinne.bechtold@example.com',
#    'login': {'uuid': '2da0c541-50e3-4dbe-bdd2-27c628352887',
#     'username': 'silvercat179',
#     'password': 'bimmer',
#     'salt': '54uBRaLk',
#     'md5': '90532443d678a0672ac0b565e0312e8d',
#     'sha1': 'c1ddbf6ec4a28a14d210135b6cd881cb6225adf6',
#     'sha256': '5ef0fc5230338e1017c21e80c0bb5ad7551ce2b30d5bf483278ec2b9f50397d3'},
#    'dob': {'date': '1951-03-18T08:13:42.822Z', 'age': 73},
#    'registered': {'date': '2007-05-22T10:14:16.518Z', 'age': 17},
#    'phone': '0052-4394906',
#    'cell': '0179-6827550',
#    'id': {'name': 'SVNR', 'value': '17 180351 B 963'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/92.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/92.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/92.jpg'},
#    'nat': 'DE'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Serditko', 'last': 'Sas'},
#    'location': {'street': {'number': 2607, 'name': 'Arhitektora Pauchenka'},
#     'city': 'Bershad',
#     'state': 'Chernivecka',
#     'country': 'Ukraine',
#     'postcode': 17141,
#     'coordinates': {'latitude': '73.1921', 'longitude': '141.3223'},
#     'timezone': {'offset': '-8:00',
#      'description': 'Pacific Time (US & Canada)'}},
#    'email': 'serditko.sas@example.com',
#    'login': {'uuid': '1ba00cdc-38af-46d8-84e8-d7deb754e0f6',
#     'username': 'greenkoala521',
#     'password': 'mermaid',
#     'salt': 'U683m4Og',
#     'md5': '8898eaa4af05d36a3a5aca2a338df70e',
#     'sha1': '33a3256afffd61b41108692223da8de61b2e7b47',
#     'sha256': 'c6b5b4b88be183ef7fcbaa8252c2cdbc29774f7cbcbaf78d2ee9b870634c1da3'},
#    'dob': {'date': '1969-12-10T23:05:58.008Z', 'age': 54},
#    'registered': {'date': '2018-02-04T04:00:00.698Z', 'age': 6},
#    'phone': '(066) M50-5181',
#    'cell': '(098) A40-0664',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/65.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/65.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/65.jpg'},
#    'nat': 'UA'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Christopher', 'last': 'Weimann'},
#    'location': {'street': {'number': 3194, 'name': 'Rosenweg'},
#     'city': 'Selbitz',
#     'state': 'Rheinland-Pfalz',
#     'country': 'Germany',
#     'postcode': 76990,
#     'coordinates': {'latitude': '82.0560', 'longitude': '80.5234'},
#     'timezone': {'offset': '-3:00',
#      'description': 'Brazil, Buenos Aires, Georgetown'}},
#    'email': 'christopher.weimann@example.com',
#    'login': {'uuid': '45a44aff-3e5c-4d32-b104-ba9d7d40661b',
#     'username': 'goldenbutterfly441',
#     'password': 'nikki1',
#     'salt': 'Dhn69w3t',
#     'md5': '61ebb95c9c33a8d5e5a4a87e1f7bf0f1',
#     'sha1': '72e408c5da42786d16b22a8aa51bec17f4030e04',
#     'sha256': '43adb4294da7ba1dffd15591decb5638411ab2838a3054037bbdbf449cdf8018'},
#    'dob': {'date': '1957-03-22T01:26:10.762Z', 'age': 67},
#    'registered': {'date': '2005-07-02T00:52:53.987Z', 'age': 19},
#    'phone': '0464-2041396',
#    'cell': '0175-2227515',
#    'id': {'name': 'SVNR', 'value': '08 210357 W 236'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/79.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/79.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/79.jpg'},
#    'nat': 'DE'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Lilja', 'last': 'Hokkanen'},
#    'location': {'street': {'number': 4047, 'name': 'Pirkankatu'},
#     'city': 'Iitti',
#     'state': 'Northern Savonia',
#     'country': 'Finland',
#     'postcode': 52943,
#     'coordinates': {'latitude': '-32.4576', 'longitude': '-84.4590'},
#     'timezone': {'offset': '-7:00',
#      'description': 'Mountain Time (US & Canada)'}},
#    'email': 'lilja.hokkanen@example.com',
#    'login': {'uuid': '1e4e2899-7f46-4330-9ef8-cb3cf925fbcb',
#     'username': 'beautifulwolf307',
#     'password': 'scotland',
#     'salt': '0KmwnAKy',
#     'md5': 'a7f3f3e2a1f3b3919810c780c20e9484',
#     'sha1': 'fbae05b0ac763e69b423e903a457f60fb52218dd',
#     'sha256': 'e248f00f0df04ba0bf4596ba60e75b5c49ed32b5a0656152c6473561bf47fc44'},
#    'dob': {'date': '1956-09-29T07:46:19.632Z', 'age': 68},
#    'registered': {'date': '2008-04-07T06:32:58.367Z', 'age': 16},
#    'phone': '09-021-188',
#    'cell': '041-813-96-74',
#    'id': {'name': 'HETU', 'value': 'NaNNA568undefined'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/37.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/37.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/37.jpg'},
#    'nat': 'FI'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Dora', 'last': 'Wood'},
#    'location': {'street': {'number': 38, 'name': 'Railroad St'},
#     'city': 'Maitland',
#     'state': 'Australian Capital Territory',
#     'country': 'Australia',
#     'postcode': 8709,
#     'coordinates': {'latitude': '-64.0872', 'longitude': '-91.6053'},
#     'timezone': {'offset': '+11:00',
#      'description': 'Magadan, Solomon Islands, New Caledonia'}},
#    'email': 'dora.wood@example.com',
#    'login': {'uuid': '7a7276c2-0123-4bab-b136-8eff4bb5ba8a',
#     'username': 'blackostrich589',
#     'password': 'sugar',
#     'salt': 'q4GJMVzQ',
#     'md5': '504b79aaec804a32fa71cf65ce7a4efe',
#     'sha1': '23fa9eae4ad112dd0a1ff8da0ab750fe2d262c7e',
#     'sha256': 'c8aa523237ff1f479e131b8b40ca981d05d597bde24d08c6a5108583d4908ef3'},
#    'dob': {'date': '1996-04-22T15:42:40.318Z', 'age': 28},
#    'registered': {'date': '2016-01-04T05:07:29.469Z', 'age': 8},
#    'phone': '04-9559-2539',
#    'cell': '0491-312-818',
#    'id': {'name': 'TFN', 'value': '242567638'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/60.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/60.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/60.jpg'},
#    'nat': 'AU'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'August', 'last': 'Hansen'},
#    'location': {'street': {'number': 5330, 'name': 'Herningvej'},
#     'city': 'Nørre Sundby',
#     'state': 'Nordjylland',
#     'country': 'Denmark',
#     'postcode': 22413,
#     'coordinates': {'latitude': '6.5306', 'longitude': '44.3218'},
#     'timezone': {'offset': '-5:00',
#      'description': 'Eastern Time (US & Canada), Bogota, Lima'}},
#    'email': 'august.hansen@example.com',
#    'login': {'uuid': '6314958a-d92e-4650-b3e9-6654e15e2ea4',
#     'username': 'purplezebra494',
#     'password': 'magelan',
#     'salt': '2J3yzSPW',
#     'md5': '63f74c0fa8f56b0dce9084c549e87075',
#     'sha1': 'a937a137969a47e1c67db66e7f41e54b446f5b1c',
#     'sha256': 'ad2774be8e7af7baba4b5ce1c7e16d076019ea71930de9db2ad19b6fd443ecd6'},
#    'dob': {'date': '1963-10-20T01:07:36.617Z', 'age': 61},
#    'registered': {'date': '2004-05-19T03:31:42.170Z', 'age': 20},
#    'phone': '81594214',
#    'cell': '24499027',
#    'id': {'name': 'CPR', 'value': '191063-3343'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/57.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/57.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/57.jpg'},
#    'nat': 'DK'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'محمد', 'last': 'کامروا'},
#    'location': {'street': {'number': 3806, 'name': 'شهید بهشتی'},
#     'city': 'قم',
#     'state': 'مرکزی',
#     'country': 'Iran',
#     'postcode': 82295,
#     'coordinates': {'latitude': '-75.0694', 'longitude': '-83.3257'},
#     'timezone': {'offset': '-6:00',
#      'description': 'Central Time (US & Canada), Mexico City'}},
#    'email': 'mhmd.khmrw@example.com',
#    'login': {'uuid': '461ec2eb-6be9-4e42-84dd-90777e1679c0',
#     'username': 'crazymouse897',
#     'password': 'gore',
#     'salt': '5YbrnnoZ',
#     'md5': 'df7cbcf86a89274a66b1dab4d3798f75',
#     'sha1': '7bbddffb77f621671b2a2669edf12c70a770fdf3',
#     'sha256': 'b114919ac2c8e86e37aae0409f9cc2ce661182c5292b7786bc211431a49bbc9d'},
#    'dob': {'date': '1965-02-20T18:06:53.040Z', 'age': 59},
#    'registered': {'date': '2015-07-23T00:15:32.633Z', 'age': 9},
#    'phone': '073-62832502',
#    'cell': '0944-684-3563',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/7.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/7.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/7.jpg'},
#    'nat': 'IR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Oliver', 'last': 'Lammi'},
#    'location': {'street': {'number': 3773, 'name': 'Verkatehtaankatu'},
#     'city': 'Enontekiö',
#     'state': 'Ostrobothnia',
#     'country': 'Finland',
#     'postcode': 66644,
#     'coordinates': {'latitude': '-83.6495', 'longitude': '165.1124'},
#     'timezone': {'offset': '+11:00',
#      'description': 'Magadan, Solomon Islands, New Caledonia'}},
#    'email': 'oliver.lammi@example.com',
#    'login': {'uuid': '923d306d-daf4-4cee-97b0-922c2114f184',
#     'username': 'happycat189',
#     'password': 'iiii',
#     'salt': 'o1xHu5km',
#     'md5': '65183a0040d1585f0d95e6fb474152bd',
#     'sha1': 'd9ce5a99e44e228c1d66d93c09d13a78bd8afcce',
#     'sha256': 'de66edc02b587406f8f7351424f1a621ba39bbb6b28448bf101ea3af6821fc8f'},
#    'dob': {'date': '1982-12-11T09:18:33.445Z', 'age': 41},
#    'registered': {'date': '2019-09-30T20:23:32.921Z', 'age': 5},
#    'phone': '03-910-012',
#    'cell': '043-036-06-59',
#    'id': {'name': 'HETU', 'value': 'NaNNA033undefined'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/99.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/99.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/99.jpg'},
#    'nat': 'FI'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Dylan', 'last': 'Hall'},
#    'location': {'street': {'number': 5523, 'name': 'Devonport Road'},
#     'city': 'Wellington',
#     'state': "Hawke'S Bay",
#     'country': 'New Zealand',
#     'postcode': 25585,
#     'coordinates': {'latitude': '-1.0148', 'longitude': '-52.2520'},
#     'timezone': {'offset': '-8:00',
#      'description': 'Pacific Time (US & Canada)'}},
#    'email': 'dylan.hall@example.com',
#    'login': {'uuid': 'f6e1af9d-4c98-402e-9e3c-c24a1f1befe3',
#     'username': 'heavycat791',
#     'password': 'smile',
#     'salt': 'C1xsoF7F',
#     'md5': '4f2a175d141235b5105fad452356db05',
#     'sha1': '3a8c448f6ede85c08c5fe66bd4065aa8580d9e28',
#     'sha256': '61fd5b35c4035442254af024a8decd258718b10ba0e521058dfe819793ff4132'},
#    'dob': {'date': '1992-07-05T19:58:03.736Z', 'age': 32},
#    'registered': {'date': '2009-09-21T10:40:35.540Z', 'age': 15},
#    'phone': '(527)-269-6086',
#    'cell': '(677)-898-3829',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/19.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/19.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/19.jpg'},
#    'nat': 'NZ'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Celso', 'last': 'Silva'},
#    'location': {'street': {'number': 9372, 'name': 'Rua Santa Rita '},
#     'city': 'Feira de Santana',
#     'state': 'Pernambuco',
#     'country': 'Brazil',
#     'postcode': 49452,
#     'coordinates': {'latitude': '70.6262', 'longitude': '55.0507'},
#     'timezone': {'offset': '-5:00',
#      'description': 'Eastern Time (US & Canada), Bogota, Lima'}},
#    'email': 'celso.silva@example.com',
#    'login': {'uuid': '195777ca-1781-482d-9d06-00ab7372f55c',
#     'username': 'silverpeacock561',
#     'password': 'sneaky',
#     'salt': 'fdGik8go',
#     'md5': '4301324444fd20f5459b77c58d3def38',
#     'sha1': '8bd9c81c577f7b756aeb6d5ef36fde662b1cccdf',
#     'sha256': '9f9fa934337c293e707344f0b6738ba753f02cdb0c83976bf86ef8fb8dc491c1'},
#    'dob': {'date': '1963-10-10T00:50:36.170Z', 'age': 61},
#    'registered': {'date': '2011-03-29T09:37:47.271Z', 'age': 13},
#    'phone': '(54) 7995-4470',
#    'cell': '(79) 8375-4429',
#    'id': {'name': 'CPF', 'value': '607.706.544-17'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/58.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/58.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/58.jpg'},
#    'nat': 'BR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'George', 'last': 'Bradley'},
#    'location': {'street': {'number': 7037, 'name': 'Ash Dr'},
#     'city': 'Dubbo',
#     'state': 'New South Wales',
#     'country': 'Australia',
#     'postcode': 8222,
#     'coordinates': {'latitude': '55.3816', 'longitude': '47.1116'},
#     'timezone': {'offset': '+3:30', 'description': 'Tehran'}},
#    'email': 'george.bradley@example.com',
#    'login': {'uuid': 'b713ef5e-4a51-4632-8697-30625fa9434c',
#     'username': 'lazymeercat217',
#     'password': 'intel',
#     'salt': 'pLQeunAK',
#     'md5': 'f900be34d3e123f3562e080a1b291dad',
#     'sha1': '77f26b9ee1f6cb19b164687cc58e8bd6a4a52294',
#     'sha256': '500375e0f245658020da7b71c4f88b8cbd7e7c6f72c973fbb5d00dea8f218b2c'},
#    'dob': {'date': '1983-03-23T13:59:45.480Z', 'age': 41},
#    'registered': {'date': '2015-11-07T06:16:56.732Z', 'age': 9},
#    'phone': '03-2353-3011',
#    'cell': '0447-536-955',
#    'id': {'name': 'TFN', 'value': '562159534'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/2.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/2.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/2.jpg'},
#    'nat': 'AU'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Svitan', 'last': 'Zagrebelniy'},
#    'location': {'street': {'number': 7542, 'name': 'Taganchanskiy provulok'},
#     'city': 'Reshetilivka',
#     'state': 'Mikolayivska',
#     'country': 'Ukraine',
#     'postcode': 40762,
#     'coordinates': {'latitude': '17.2472', 'longitude': '-118.0128'},
#     'timezone': {'offset': '-1:00',
#      'description': 'Azores, Cape Verde Islands'}},
#    'email': 'svitan.zagrebelniy@example.com',
#    'login': {'uuid': '807a5b72-9268-4277-b935-3696c0f3346f',
#     'username': 'reddog759',
#     'password': 'spooky',
#     'salt': 'UqkQ6T8F',
#     'md5': '25d62f69b73f84398d6f3cf2edaa1013',
#     'sha1': '4b12092922b436d0ff66646340f34a6109b41a71',
#     'sha256': 'facf4c67369df8ec1ee41556a0e0c8c8bc6bfbed0ea2433033b803910b26766f'},
#    'dob': {'date': '1959-07-15T19:35:45.612Z', 'age': 65},
#    'registered': {'date': '2010-08-18T11:50:51.386Z', 'age': 14},
#    'phone': '(099) F82-4096',
#    'cell': '(068) A80-0176',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/94.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/94.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/94.jpg'},
#    'nat': 'UA'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Claas', 'last': 'Geßner'},
#    'location': {'street': {'number': 7938, 'name': 'Danziger Straße'},
#     'city': 'Lauenburg/Elbe',
#     'state': 'Brandenburg',
#     'country': 'Germany',
#     'postcode': 92341,
#     'coordinates': {'latitude': '-78.2710', 'longitude': '-74.7383'},
#     'timezone': {'offset': '-2:00', 'description': 'Mid-Atlantic'}},
#    'email': 'claas.gessner@example.com',
#    'login': {'uuid': '31dd1c25-fac7-49ae-8c4f-4f0a8064e899',
#     'username': 'smallcat554',
#     'password': 'nimitz',
#     'salt': 'kAbC4JPX',
#     'md5': 'dfe3ec307908957c09d8878346136dd4',
#     'sha1': 'd616f9336cfdebc86354533c5ab01aecfcf0eb47',
#     'sha256': 'ee47c350e885cafffc8309700631f89b1d21bf2c185c16001b0ecdd705d789cb'},
#    'dob': {'date': '1987-06-03T03:16:37.227Z', 'age': 37},
#    'registered': {'date': '2004-04-20T15:33:37.319Z', 'age': 20},
#    'phone': '0932-3107057',
#    'cell': '0179-8592246',
#    'id': {'name': 'SVNR', 'value': '49 020687 G 197'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/91.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/91.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/91.jpg'},
#    'nat': 'DE'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Dulcilene', 'last': 'Ribeiro'},
#    'location': {'street': {'number': 3135, 'name': 'Rua Rio de Janeiro '},
#     'city': 'Águas Lindas de Goiás',
#     'state': 'Rio Grande do Norte',
#     'country': 'Brazil',
#     'postcode': 91439,
#     'coordinates': {'latitude': '46.8516', 'longitude': '-34.1784'},
#     'timezone': {'offset': '-6:00',
#      'description': 'Central Time (US & Canada), Mexico City'}},
#    'email': 'dulcilene.ribeiro@example.com',
#    'login': {'uuid': 'ad2a8ea9-7f99-4f49-afe1-624d2d3649ac',
#     'username': 'whiteduck228',
#     'password': 'holden',
#     'salt': '2le1ZhV1',
#     'md5': 'dc53cbf953df90e778df476f8ed67d3f',
#     'sha1': 'd2fb40db4865f27bb56258d4a2f23959a7410934',
#     'sha256': '85c01e0633216fd9e9602377c51a844c913b6baa3133ee536a6dc93dd09ea622'},
#    'dob': {'date': '1971-11-22T00:26:01.447Z', 'age': 53},
#    'registered': {'date': '2017-02-16T07:48:31.821Z', 'age': 7},
#    'phone': '(06) 7700-3494',
#    'cell': '(98) 2179-9829',
#    'id': {'name': 'CPF', 'value': '339.122.942-91'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/10.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/10.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/10.jpg'},
#    'nat': 'BR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Ethan', 'last': 'Tremblay'},
#    'location': {'street': {'number': 6528, 'name': 'West Ave'},
#     'city': 'Port Elgin',
#     'state': 'Ontario',
#     'country': 'Canada',
#     'postcode': 'S6E 7D2',
#     'coordinates': {'latitude': '27.0720', 'longitude': '-54.3955'},
#     'timezone': {'offset': '+4:30', 'description': 'Kabul'}},
#    'email': 'ethan.tremblay@example.com',
#    'login': {'uuid': 'dd441338-48a2-4d9d-a6ba-c9af7519d29e',
#     'username': 'whitebutterfly420',
#     'password': 'bacardi',
#     'salt': 'DM6aGzpa',
#     'md5': '06224536c86fae88732050777fd71f60',
#     'sha1': '0e16a2de2508ae9fbbdd766e0e24364d88725e0f',
#     'sha256': '3694bc92a5010295a7e5e1b25740f7e7430c84d8f9de0cc5bc15d1dd2f737050'},
#    'dob': {'date': '1967-03-19T19:23:44.975Z', 'age': 57},
#    'registered': {'date': '2019-04-28T07:40:05.069Z', 'age': 5},
#    'phone': 'L35 J56-9136',
#    'cell': 'H55 V42-6893',
#    'id': {'name': 'SIN', 'value': '372554824'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/94.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/94.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/94.jpg'},
#    'nat': 'CA'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Marius', 'last': 'Muller'},
#    'location': {'street': {'number': 6536, 'name': 'Rue Duguesclin'},
#     'city': 'Tourcoing',
#     'state': 'Drôme',
#     'country': 'France',
#     'postcode': 63024,
#     'coordinates': {'latitude': '-9.1528', 'longitude': '-97.6916'},
#     'timezone': {'offset': '+3:00',
#      'description': 'Baghdad, Riyadh, Moscow, St. Petersburg'}},
#    'email': 'marius.muller@example.com',
#    'login': {'uuid': '17466ff0-3b65-4759-bbd3-66bacec04333',
#     'username': 'goldensnake921',
#     'password': 'winter1',
#     'salt': '5CMwENRj',
#     'md5': 'c2674aebcff0df7049ae0244fd1d0a0c',
#     'sha1': 'be756bfaf4e1f753f423f522a7058152715de92b',
#     'sha256': '9986e53466df0b14423e642299f629602d2d56447feee8bd617d004a54d99ba1'},
#    'dob': {'date': '1959-08-24T23:29:20.403Z', 'age': 65},
#    'registered': {'date': '2018-09-18T05:34:57.904Z', 'age': 6},
#    'phone': '04-11-68-50-99',
#    'cell': '06-59-91-35-59',
#    'id': {'name': 'INSEE', 'value': '1590710664789 54'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/47.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/47.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/47.jpg'},
#    'nat': 'FR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Rafael', 'last': 'Guerin'},
#    'location': {'street': {'number': 4151, 'name': 'Rue Bony'},
#     'city': 'Bordeaux',
#     'state': 'Tarn-et-Garonne',
#     'country': 'France',
#     'postcode': 62293,
#     'coordinates': {'latitude': '60.2031', 'longitude': '-35.1387'},
#     'timezone': {'offset': '+3:30', 'description': 'Tehran'}},
#    'email': 'rafael.guerin@example.com',
#    'login': {'uuid': '4ae5a1c5-a3d5-4480-8779-d7599557b7f6',
#     'username': 'yellowzebra248',
#     'password': 'taco',
#     'salt': 'US04bYYI',
#     'md5': '6e3965ad8f1240a5f898b6a409bcf05f',
#     'sha1': 'f82722d65ad7e8c23647de53aa6321ac7f9d89bc',
#     'sha256': 'fb9457adb821e992e72b331c9af520548c038e7ab7524a16c26300db16b1ef0e'},
#    'dob': {'date': '1946-10-27T10:24:33.361Z', 'age': 78},
#    'registered': {'date': '2005-01-03T02:14:24.288Z', 'age': 19},
#    'phone': '04-53-90-82-87',
#    'cell': '06-98-56-01-86',
#    'id': {'name': 'INSEE', 'value': '1460961234078 56'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/92.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/92.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/92.jpg'},
#    'nat': 'FR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Marcus', 'last': 'Andersen'},
#    'location': {'street': {'number': 765, 'name': 'Herluf Trolles Vej'},
#     'city': 'Brondby',
#     'state': 'Midtjylland',
#     'country': 'Denmark',
#     'postcode': 39588,
#     'coordinates': {'latitude': '77.6549', 'longitude': '-168.4909'},
#     'timezone': {'offset': '+6:00', 'description': 'Almaty, Dhaka, Colombo'}},
#    'email': 'marcus.andersen@example.com',
#    'login': {'uuid': '7a3d685e-2376-421a-9f3e-11023414b1a8',
#     'username': 'redrabbit827',
#     'password': 'kitty1',
#     'salt': 'XxKueKJA',
#     'md5': 'dafeb1385c5fb33a75028e2dea5d5072',
#     'sha1': 'd086c4d59470236c6c98058101e1c774d968b92d',
#     'sha256': '7fcd0a9159608591341a5941dc89a80b1a193363dc05472f15a070007b37affc'},
#    'dob': {'date': '1978-04-04T15:10:45.181Z', 'age': 46},
#    'registered': {'date': '2002-05-04T05:58:35.305Z', 'age': 22},
#    'phone': '98189250',
#    'cell': '72442472',
#    'id': {'name': 'CPR', 'value': '040478-6781'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/29.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/29.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/29.jpg'},
#    'nat': 'DK'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'میلاد', 'last': 'محمدخان'},
#    'location': {'street': {'number': 2442, 'name': '30 تیر'},
#     'city': 'خوی',
#     'state': 'خوزستان',
#     'country': 'Iran',
#     'postcode': 88042,
#     'coordinates': {'latitude': '75.1453', 'longitude': '-154.9594'},
#     'timezone': {'offset': '+2:00',
#      'description': 'Kaliningrad, South Africa'}},
#    'email': 'myld.mhmdkhn@example.com',
#    'login': {'uuid': '65c74328-3e42-47d6-838e-8d71cd5394b3',
#     'username': 'sadlion316',
#     'password': 'piercing',
#     'salt': 'XbOWlHKW',
#     'md5': 'd8bbe0f91ec2698cc06973dea3cabea9',
#     'sha1': '4fa92924703553d61692a87e4629c4ae6816a7ce',
#     'sha256': 'c728a3a26ec78980ac20bd40c01d8852bdf79f63c2e5eabffb57bfdf1e4f51b4'},
#    'dob': {'date': '1973-09-30T19:27:02.444Z', 'age': 51},
#    'registered': {'date': '2009-07-12T19:47:45.132Z', 'age': 15},
#    'phone': '005-75543138',
#    'cell': '0928-102-4557',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/71.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/71.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/71.jpg'},
#    'nat': 'IR'},
#   {'gender': 'female',
#    'name': {'title': 'Ms', 'first': 'Cathy', 'last': 'Clark'},
#    'location': {'street': {'number': 1676, 'name': 'The Crescent'},
#     'city': 'Athy',
#     'state': 'Leitrim',
#     'country': 'Ireland',
#     'postcode': 44451,
#     'coordinates': {'latitude': '32.4383', 'longitude': '155.9387'},
#     'timezone': {'offset': '-10:00', 'description': 'Hawaii'}},
#    'email': 'cathy.clark@example.com',
#    'login': {'uuid': 'a0d9accd-ee6d-43f1-b3e4-ea49710822f1',
#     'username': 'goldenswan948',
#     'password': 'sixsix',
#     'salt': 'L0WFPEsc',
#     'md5': 'd2db2a0c8497eee5f4d8407cb841d42a',
#     'sha1': '991a6fe59a86b99d4e9651249c8960cb099579c6',
#     'sha256': '0878bfbb98c711b9758767a445ab863b56ca2479c5722a2af7a06ec618ecf185'},
#    'dob': {'date': '1979-01-28T07:55:35.990Z', 'age': 45},
#    'registered': {'date': '2010-02-02T04:55:36.671Z', 'age': 14},
#    'phone': '061-040-7951',
#    'cell': '081-555-9950',
#    'id': {'name': 'PPS', 'value': '7167454T'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/62.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/62.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/62.jpg'},
#    'nat': 'IE'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Dhanush', 'last': 'Mardhekar'},
#    'location': {'street': {'number': 1462, 'name': 'Mirza Ismail Rd'},
#     'city': 'Hazaribagh',
#     'state': 'Puducherry',
#     'country': 'India',
#     'postcode': 48805,
#     'coordinates': {'latitude': '-49.2193', 'longitude': '118.1103'},
#     'timezone': {'offset': '-3:00',
#      'description': 'Brazil, Buenos Aires, Georgetown'}},
#    'email': 'dhanush.mardhekar@example.com',
#    'login': {'uuid': 'cb857987-cfe8-467c-8bfe-5b9764f91cb0',
#     'username': 'blackkoala294',
#     'password': 'sales',
#     'salt': 'EwE7LWxy',
#     'md5': '6ab571fe0ce317ac166aa99d464d374a',
#     'sha1': '26ec4155e3119e7a7419f4c49c955d2e23113e39',
#     'sha256': 'b9ce081e4b74868455603599ea8c70192cd35a642d139dfca78637a050860186'},
#    'dob': {'date': '1976-11-11T13:34:48.646Z', 'age': 48},
#    'registered': {'date': '2008-07-17T16:05:11.164Z', 'age': 16},
#    'phone': '9726286092',
#    'cell': '8787094980',
#    'id': {'name': 'UIDAI', 'value': '352238347064'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/15.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/15.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/15.jpg'},
#    'nat': 'IN'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Dionísio', 'last': 'Silva'},
#    'location': {'street': {'number': 7537, 'name': 'Rua Dom Pedro Ii '},
#     'city': 'Guarujá',
#     'state': 'Sergipe',
#     'country': 'Brazil',
#     'postcode': 90531,
#     'coordinates': {'latitude': '35.2714', 'longitude': '14.8092'},
#     'timezone': {'offset': '+7:00', 'description': 'Bangkok, Hanoi, Jakarta'}},
#    'email': 'dionisio.silva@example.com',
#    'login': {'uuid': '672b0361-9b05-4263-9a15-3697892aa063',
#     'username': 'greenmouse753',
#     'password': 'iiiiiii',
#     'salt': 'b39E8abb',
#     'md5': '6e3bd7ce69a9f33dae2f4273c0b24bce',
#     'sha1': 'b50f49ead36755d1949b417c696b8c1569f18bef',
#     'sha256': 'b0d5462a2006620066fc92c25bf58e33cc8ad603ddcac0287b0edd676856f49e'},
#    'dob': {'date': '1979-10-22T13:10:22.201Z', 'age': 45},
#    'registered': {'date': '2004-09-15T08:30:04.000Z', 'age': 20},
#    'phone': '(15) 2437-1618',
#    'cell': '(80) 2714-6302',
#    'id': {'name': 'CPF', 'value': '051.026.227-18'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/36.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/36.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/36.jpg'},
#    'nat': 'BR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Brayden', 'last': 'Day'},
#    'location': {'street': {'number': 2241, 'name': 'Fincher Rd'},
#     'city': 'Winston–Salem',
#     'state': 'Oklahoma',
#     'country': 'United States',
#     'postcode': 36635,
#     'coordinates': {'latitude': '-26.8136', 'longitude': '31.5341'},
#     'timezone': {'offset': '+3:00',
#      'description': 'Baghdad, Riyadh, Moscow, St. Petersburg'}},
#    'email': 'brayden.day@example.com',
#    'login': {'uuid': '550227b8-69f9-488a-828e-957de5c56cdb',
#     'username': 'orangemouse620',
#     'password': 'combat',
#     'salt': '5BKNVoMD',
#     'md5': '836f46591eef49ef1ae94c88d0915565',
#     'sha1': 'db88bd295c0a9fd8ea96321ef05c5bac38e60ca6',
#     'sha256': '37bd8bd13499f9e63b805fec0502d6cba5ab85f87f3f2f58923e435e03e3df2d'},
#    'dob': {'date': '1945-03-22T16:25:38.839Z', 'age': 79},
#    'registered': {'date': '2008-12-18T10:15:13.282Z', 'age': 15},
#    'phone': '(947) 534-3739',
#    'cell': '(850) 798-4108',
#    'id': {'name': 'SSN', 'value': '721-72-6816'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/89.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/89.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/89.jpg'},
#    'nat': 'US'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Serenity', 'last': 'Chambers'},
#    'location': {'street': {'number': 3828, 'name': 'Marsh Ln'},
#     'city': 'Tweed',
#     'state': 'Victoria',
#     'country': 'Australia',
#     'postcode': 6140,
#     'coordinates': {'latitude': '13.1124', 'longitude': '-56.9519'},
#     'timezone': {'offset': '+9:00',
#      'description': 'Tokyo, Seoul, Osaka, Sapporo, Yakutsk'}},
#    'email': 'serenity.chambers@example.com',
#    'login': {'uuid': 'b42bebf8-da2b-446f-b3d3-61fa50e013c9',
#     'username': 'blackfrog669',
#     'password': 'balloons',
#     'salt': 'iLYkK5OF',
#     'md5': '08a5902e6a38b3543542dc00b284c447',
#     'sha1': '09c3f2ab8b8b8e7557fcb62053731f1c54f14b93',
#     'sha256': '8a861e443e5c09efcd2291b7bd8918cb289f9bcb79f309bb1e7bb4e30626f7fc'},
#    'dob': {'date': '1993-07-18T02:46:42.202Z', 'age': 31},
#    'registered': {'date': '2018-10-12T07:37:19.227Z', 'age': 6},
#    'phone': '03-1382-3856',
#    'cell': '0420-785-962',
#    'id': {'name': 'TFN', 'value': '560615035'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/70.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/70.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/70.jpg'},
#    'nat': 'AU'},
#   {'gender': 'female',
#    'name': {'title': 'Ms', 'first': 'Yasmin', 'last': 'Kringstad'},
#    'location': {'street': {'number': 2967, 'name': 'Rådhusgata'},
#     'city': 'Svelgen',
#     'state': 'Vestfold',
#     'country': 'Norway',
#     'postcode': '6504',
#     'coordinates': {'latitude': '-54.0433', 'longitude': '-22.5170'},
#     'timezone': {'offset': '-5:00',
#      'description': 'Eastern Time (US & Canada), Bogota, Lima'}},
#    'email': 'yasmin.kringstad@example.com',
#    'login': {'uuid': '236c373e-2607-4e9a-8ac1-8c1ef44621c0',
#     'username': 'beautifultiger788',
#     'password': 'wrestle',
#     'salt': 'XwLPrqoB',
#     'md5': 'c1247c32bfe409065f6eabe307346cf5',
#     'sha1': '443961d34115b335285fc24074d3b93d527035c4',
#     'sha256': '079060effcccce7359e6b55157323e36e373c4aed7436142d60ca38c2f7f95b1'},
#    'dob': {'date': '1983-03-21T09:04:01.019Z', 'age': 41},
#    'registered': {'date': '2015-12-31T03:46:26.722Z', 'age': 8},
#    'phone': '76315563',
#    'cell': '91353246',
#    'id': {'name': 'FN', 'value': '21038347079'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/5.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/5.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/5.jpg'},
#    'nat': 'NO'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Teo', 'last': 'Skjetne'},
#    'location': {'street': {'number': 3339, 'name': 'Borger Withs gate'},
#     'city': 'Vollen',
#     'state': 'Troms - Romsa',
#     'country': 'Norway',
#     'postcode': '0359',
#     'coordinates': {'latitude': '3.2458', 'longitude': '88.4399'},
#     'timezone': {'offset': '+11:00',
#      'description': 'Magadan, Solomon Islands, New Caledonia'}},
#    'email': 'teo.skjetne@example.com',
#    'login': {'uuid': 'ee9e336a-76c0-4e3d-8359-fbed21dd1cd7',
#     'username': 'angrybird572',
#     'password': 'trick',
#     'salt': 'Jx2obELl',
#     'md5': 'f8edc85ed275a85d1261027e75d5a303',
#     'sha1': '4a0cb518e7ec3838cc34b3f417eeece4367af5d8',
#     'sha256': 'ad611cc383bdf74aa4679f1ce551af416278ad7a72398734bbdd9e67402fa6bb'},
#    'dob': {'date': '1991-09-25T22:17:43.310Z', 'age': 33},
#    'registered': {'date': '2009-08-26T23:45:59.250Z', 'age': 15},
#    'phone': '27583367',
#    'cell': '92200369',
#    'id': {'name': 'FN', 'value': '25099139504'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/71.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/71.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/71.jpg'},
#    'nat': 'NO'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Joshua', 'last': 'Lofthus'},
#    'location': {'street': {'number': 2375, 'name': 'Tidemands gate'},
#     'city': 'Tjøme',
#     'state': 'Akershus',
#     'country': 'Norway',
#     'postcode': '4735',
#     'coordinates': {'latitude': '81.4821', 'longitude': '-104.6050'},
#     'timezone': {'offset': '-1:00',
#      'description': 'Azores, Cape Verde Islands'}},
# ...
#     'coordinates': {'latitude': '74.2505', 'longitude': '5.1648'},
#     'timezone': {'offset': '+9:30', 'description': 'Adelaide, Darwin'}},
#    'email': 'ashley.jennings@example.com',
#    'login': {'uuid': 'f357ec84-62bb-4686-8d01-d6c9a63eee3c',
#     'username': 'purplekoala329',
#     'password': 'peewee',
#     'salt': 'i0P5pdZj',
#     'md5': '561df50267d91c08d88290a4cccc0777',
#     'sha1': '20bfc242ea9d8380e7677144fa488ba974d94864',
#     'sha256': '7b82bddf8afba1d506b745392c89040e441e9244540df8b0b250d9fa10c4dbdf'},
#    'dob': {'date': '1974-08-09T07:52:02.198Z', 'age': 50},
#    'registered': {'date': '2021-02-22T12:32:48.913Z', 'age': 3},
#    'phone': '041-066-4846',
#    'cell': '081-185-7982',
#    'id': {'name': 'PPS', 'value': '7717529T'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/79.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/79.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/79.jpg'},
#    'nat': 'IE'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Jesse', 'last': 'Byrd'},
#    'location': {'street': {'number': 1498, 'name': 'Lovers Ln'},
#     'city': 'San Bernardino',
#     'state': 'Minnesota',
#     'country': 'United States',
#     'postcode': 86888,
#     'coordinates': {'latitude': '61.5963', 'longitude': '74.0693'},
#     'timezone': {'offset': '-2:00', 'description': 'Mid-Atlantic'}},
#    'email': 'jesse.byrd@example.com',
#    'login': {'uuid': '911f8ffd-f7cd-41d0-9484-04d0116e6fbb',
#     'username': 'purplekoala257',
#     'password': 'office',
#     'salt': 'hsbfKFVg',
#     'md5': 'b254b9578ca50c0ed02671eca9b823d2',
#     'sha1': '4b7bb26a9ffae745e31125330e13d21a6f2f37a1',
#     'sha256': 'a4bcd309647bc7634cdd2dc25e4a84168322a2491d4029fc6c11dbb5bcc3890b'},
#    'dob': {'date': '1958-03-30T13:35:21.284Z', 'age': 66},
#    'registered': {'date': '2007-11-11T16:38:50.834Z', 'age': 17},
#    'phone': '(369) 503-3498',
#    'cell': '(419) 992-1669',
#    'id': {'name': 'SSN', 'value': '600-68-7039'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/22.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/22.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/22.jpg'},
#    'nat': 'US'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Souraya', 'last': 'Van den Doel'},
#    'location': {'street': {'number': 8848, 'name': 'Braamsluiper'},
#     'city': 'Emst',
#     'state': 'Gelderland',
#     'country': 'Netherlands',
#     'postcode': '3110 WH',
#     'coordinates': {'latitude': '73.4456', 'longitude': '-80.6146'},
#     'timezone': {'offset': '0:00',
#      'description': 'Western Europe Time, London, Lisbon, Casablanca'}},
#    'email': 'souraya.vandendoel@example.com',
#    'login': {'uuid': 'd56817a6-a5e4-4056-94e9-3d1a0529f7b6',
#     'username': 'organicduck193',
#     'password': 'hores',
#     'salt': 'vCH5k8Ap',
#     'md5': '8c0c0d6f19b7f2bc37a77dfbf061ab0d',
#     'sha1': '66f9649f11d148ddba833d0318746d663cc365f3',
#     'sha256': '71abc2ac358d6dbeede959f246668d4ef508cdf8091e62efa15f85180da57fda'},
#    'dob': {'date': '1983-08-06T05:00:35.444Z', 'age': 41},
#    'registered': {'date': '2004-07-26T03:06:44.569Z', 'age': 20},
#    'phone': '(095) 9411419',
#    'cell': '(06) 55978036',
#    'id': {'name': 'BSN', 'value': '97540834'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/54.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/54.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/54.jpg'},
#    'nat': 'NL'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Lumi', 'last': 'Kyllo'},
#    'location': {'street': {'number': 8244, 'name': 'Hämeenkatu'},
#     'city': 'Suomussalmi',
#     'state': 'Satakunta',
#     'country': 'Finland',
#     'postcode': 41571,
#     'coordinates': {'latitude': '86.9190', 'longitude': '91.3240'},
#     'timezone': {'offset': '+3:00',
#      'description': 'Baghdad, Riyadh, Moscow, St. Petersburg'}},
#    'email': 'lumi.kyllo@example.com',
#    'login': {'uuid': '89bf6736-0b31-4c57-9ae0-95d4bd4ecba8',
#     'username': 'greenbutterfly787',
#     'password': 'therock',
#     'salt': 'Pn0yMUsH',
#     'md5': '43f9c34e62cb00aa9b84d29f6c69c1b7',
#     'sha1': 'df83dd32782678117e7aa698c499b22eac1e7c21',
#     'sha256': 'c6ac05f24afbbe68390ac3f32a57c0aa65b801b5710c6a4402618ce42208b77e'},
#    'dob': {'date': '1952-04-16T04:00:21.109Z', 'age': 72},
#    'registered': {'date': '2003-08-18T00:16:23.764Z', 'age': 21},
#    'phone': '06-515-741',
#    'cell': '042-429-18-52',
#    'id': {'name': 'HETU', 'value': 'NaNNA582undefined'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/63.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/63.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/63.jpg'},
#    'nat': 'FI'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Tatomir', 'last': 'Dankiv'},
#    'location': {'street': {'number': 2778, 'name': 'Ivana Ogiienka'},
#     'city': 'Rava-Ruska',
#     'state': 'Hmelnicka',
#     'country': 'Ukraine',
#     'postcode': 68565,
#     'coordinates': {'latitude': '-5.5040', 'longitude': '113.7653'},
#     'timezone': {'offset': '+4:30', 'description': 'Kabul'}},
#    'email': 'tatomir.dankiv@example.com',
#    'login': {'uuid': 'c1536c8c-9cbf-4fd3-aeaa-7505cfb15594',
#     'username': 'happypeacock577',
#     'password': 'bounce',
#     'salt': 'CLFHbbuv',
#     'md5': '96720b35d6bc1de482711fa3e8e0f8b6',
#     'sha1': '850fb0bac92330e99fea9f06ac2ba09c43837bc9',
#     'sha256': 'eea03aee252dd05480bf75e3733e9dc1a1db1e2d7f226ac6e878e077cfbaf0c4'},
#    'dob': {'date': '1953-04-01T01:45:58.792Z', 'age': 71},
#    'registered': {'date': '2005-01-22T18:18:11.023Z', 'age': 19},
#    'phone': '(098) Q88-5423',
#    'cell': '(066) P57-0799',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/45.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/45.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/45.jpg'},
#    'nat': 'UA'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Marie', 'last': 'Fabre'},
#    'location': {'street': {'number': 7248, 'name': 'Avenue Joliot Curie'},
#     'city': 'Limoges',
#     'state': 'Eure-et-Loir',
#     'country': 'France',
#     'postcode': 75994,
#     'coordinates': {'latitude': '-33.9068', 'longitude': '124.2897'},
#     'timezone': {'offset': '-2:00', 'description': 'Mid-Atlantic'}},
#    'email': 'marie.fabre@example.com',
#    'login': {'uuid': '4c6f90a7-0196-4e67-8314-64b3b38fd979',
#     'username': 'ticklishfish939',
#     'password': 'trouble1',
#     'salt': 'oUHgtOGI',
#     'md5': '817f67595e36eabc664a35731109216c',
#     'sha1': '2b169428ed8e491142f0a5279520afdca52f8f76',
#     'sha256': '4860a294dc75455303cacf7dbef8d810d259ac3294a6626af8fa8ce3fba022e1'},
#    'dob': {'date': '1958-02-15T12:21:33.622Z', 'age': 66},
#    'registered': {'date': '2008-11-05T14:20:05.287Z', 'age': 16},
#    'phone': '01-21-77-04-05',
#    'cell': '06-86-91-01-20',
#    'id': {'name': 'INSEE', 'value': '2580153454977 58'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/1.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/1.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/1.jpg'},
#    'nat': 'FR'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Lucy', 'last': 'Gonzalez'},
#    'location': {'street': {'number': 6429, 'name': 'Rue Abel-Gance'},
#     'city': 'Mulhouse',
#     'state': 'Ariège',
#     'country': 'France',
#     'postcode': 69905,
#     'coordinates': {'latitude': '48.4728', 'longitude': '-109.4446'},
#     'timezone': {'offset': '-7:00',
#      'description': 'Mountain Time (US & Canada)'}},
#    'email': 'lucy.gonzalez@example.com',
#    'login': {'uuid': 'b83b91af-39be-4673-894a-8f15ecc131a5',
#     'username': 'whitekoala392',
#     'password': 'divine',
#     'salt': 'mwWYhgrM',
#     'md5': 'a4c62190e9b513f7d6a259f88b368148',
#     'sha1': '3a615880178272fe697fd4dfb5aac33f8e731a07',
#     'sha256': '6bc351847b7a77d1a3b42e7ae0315659207877332d6537d98e546ba7d16e3808'},
#    'dob': {'date': '1955-06-03T16:36:16.180Z', 'age': 69},
#    'registered': {'date': '2011-03-18T08:21:58.950Z', 'age': 13},
#    'phone': '02-98-37-80-73',
#    'cell': '06-66-84-93-68',
#    'id': {'name': 'INSEE', 'value': '2550509668501 72'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/76.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/76.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/76.jpg'},
#    'nat': 'FR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Hilmar', 'last': 'Strobel'},
#    'location': {'street': {'number': 3417, 'name': 'Poststraße'},
#     'city': 'Plön',
#     'state': 'Bayern',
#     'country': 'Germany',
#     'postcode': 41729,
#     'coordinates': {'latitude': '68.6180', 'longitude': '123.3532'},
#     'timezone': {'offset': '-3:00',
#      'description': 'Brazil, Buenos Aires, Georgetown'}},
#    'email': 'hilmar.strobel@example.com',
#    'login': {'uuid': 'd386bcd2-f5ce-4df6-8658-0576cf36b446',
#     'username': 'ticklishleopard875',
#     'password': 'krystal',
#     'salt': 'xfV8MK7v',
#     'md5': 'edab4ae7c00d072c16ca6586ddbdd607',
#     'sha1': '095aec482460c5cfea3e36062075910324b5f5f9',
#     'sha256': '7023d939bb9f57322eb96f46434f38cda4ea7b527a732a2b2de7fa44f4386c62'},
#    'dob': {'date': '1967-06-04T03:31:38.028Z', 'age': 57},
#    'registered': {'date': '2011-02-06T18:01:19.634Z', 'age': 13},
#    'phone': '0260-4612749',
#    'cell': '0179-9008058',
#    'id': {'name': 'SVNR', 'value': '60 030667 S 166'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/30.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/30.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/30.jpg'},
#    'nat': 'DE'},
#   {'gender': 'female',
#    'name': {'title': 'Ms', 'first': 'Judy', 'last': 'Fleming'},
#    'location': {'street': {'number': 4186, 'name': 'Woodland St'},
#     'city': 'Bathurst',
#     'state': 'South Australia',
#     'country': 'Australia',
#     'postcode': 8518,
#     'coordinates': {'latitude': '-47.2356', 'longitude': '77.9652'},
#     'timezone': {'offset': '+5:45', 'description': 'Kathmandu'}},
#    'email': 'judy.fleming@example.com',
#    'login': {'uuid': '1e3aee97-76d0-43f4-91ec-a9db72df57ac',
#     'username': 'crazyostrich977',
#     'password': 'valkyrie',
#     'salt': 'veP2ZnPo',
#     'md5': 'aa905f1e557600330a3deea66c730048',
#     'sha1': '22183475adf5c25b2bbadb5ed80b9aefd5ab8816',
#     'sha256': '6d224c3ebb1cb0b9ae925d61f9399a4b62e53490d08c9f6cabd5afd0496807a7'},
#    'dob': {'date': '1972-12-18T20:49:14.679Z', 'age': 51},
#    'registered': {'date': '2004-07-09T12:18:54.230Z', 'age': 20},
#    'phone': '02-5144-7053',
#    'cell': '0458-588-440',
#    'id': {'name': 'TFN', 'value': '323634109'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/10.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/10.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/10.jpg'},
#    'nat': 'AU'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Tim', 'last': 'Barbier'},
#    'location': {'street': {'number': 3738, 'name': 'Rue du Stade'},
#     'city': 'Besançon',
#     'state': 'Paris',
#     'country': 'France',
#     'postcode': 25864,
#     'coordinates': {'latitude': '84.2775', 'longitude': '173.3869'},
#     'timezone': {'offset': '+3:30', 'description': 'Tehran'}},
#    'email': 'tim.barbier@example.com',
#    'login': {'uuid': 'aa291460-1d84-49bc-84f8-b9e224b77415',
#     'username': 'goldengoose716',
#     'password': 'sonic',
#     'salt': 'nI3w6JEe',
#     'md5': '7bbb87bb1168a4a9e630a2d7b4d9c5ad',
#     'sha1': 'd2ff79d83b00235e02bbb3f83770d6b54c0d0d98',
#     'sha256': '1ba2216d4dccf220610ec6d6eb24317f6ec34c57ba71621f31a43e116b9360e8'},
#    'dob': {'date': '1955-10-26T03:06:04.523Z', 'age': 69},
#    'registered': {'date': '2010-04-14T03:39:59.712Z', 'age': 14},
#    'phone': '05-26-25-37-29',
#    'cell': '06-25-84-42-64',
#    'id': {'name': 'INSEE', 'value': '1550963322578 10'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/7.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/7.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/7.jpg'},
#    'nat': 'FR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Taylor', 'last': 'Fisher'},
#    'location': {'street': {'number': 7525, 'name': 'North Road'},
#     'city': 'Monaghan',
#     'state': 'Clare',
#     'country': 'Ireland',
#     'postcode': 67189,
#     'coordinates': {'latitude': '-80.2678', 'longitude': '-60.1828'},
#     'timezone': {'offset': '-1:00',
#      'description': 'Azores, Cape Verde Islands'}},
#    'email': 'taylor.fisher@example.com',
#    'login': {'uuid': '35783589-ea35-48a4-83cb-d601e89c1695',
#     'username': 'angrygoose599',
#     'password': 'hitman',
#     'salt': 'DLwSK5dd',
#     'md5': 'f5442d373fe881a4b5dd40b7be233864',
#     'sha1': 'cb9545036b0ec88a3f9bf3671dd9eec1f109ba08',
#     'sha256': '11d96e723eee0de4732a1e7ca5d0387db40006eed6055f84c1deb74ddaaf2fc8'},
#    'dob': {'date': '1944-10-23T01:47:45.878Z', 'age': 80},
#    'registered': {'date': '2020-05-05T11:14:09.706Z', 'age': 4},
#    'phone': '051-032-3694',
#    'cell': '081-627-5939',
#    'id': {'name': 'PPS', 'value': '6954068T'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/42.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/42.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/42.jpg'},
#    'nat': 'IE'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Victor', 'last': 'Ginnish'},
#    'location': {'street': {'number': 2888, 'name': '9th St'},
#     'city': 'Campbellton',
#     'state': 'Ontario',
#     'country': 'Canada',
#     'postcode': 'M2V 5Y1',
#     'coordinates': {'latitude': '-59.3920', 'longitude': '127.0910'},
#     'timezone': {'offset': '+2:00',
#      'description': 'Kaliningrad, South Africa'}},
#    'email': 'victor.ginnish@example.com',
#    'login': {'uuid': '579bf00f-eac7-4ee1-985f-55f0a4a94e25',
#     'username': 'organicfish504',
#     'password': 'wilbur',
#     'salt': 'WfQc9hWa',
#     'md5': '2721ad717efd9cd3351948450642417a',
#     'sha1': 'd003227ccb975304f70234c762b0627ffe13e344',
#     'sha256': '8e46f6adfaa154f459db66819260b76f0d5b1b759d75a2e3e8746a5cd0ecd389'},
#    'dob': {'date': '1985-02-21T05:18:31.250Z', 'age': 39},
#    'registered': {'date': '2021-05-25T21:01:36.537Z', 'age': 3},
#    'phone': 'P17 S97-9360',
#    'cell': 'O10 O30-2565',
#    'id': {'name': 'SIN', 'value': '443285317'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/78.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/78.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/78.jpg'},
#    'nat': 'CA'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'رهام', 'last': 'کوتی'},
#    'location': {'street': {'number': 719, 'name': 'جمهوری اسلامی'},
#     'city': 'اردبیل',
#     'state': 'خراسان جنوبی',
#     'country': 'Iran',
#     'postcode': 40704,
#     'coordinates': {'latitude': '57.4636', 'longitude': '-155.1179'},
#     'timezone': {'offset': '-9:00', 'description': 'Alaska'}},
#    'email': 'rhm.khwty@example.com',
#    'login': {'uuid': '0a10024f-94f5-415b-a5a8-dfc7f3419abc',
#     'username': 'crazymeercat137',
#     'password': 'knight1',
#     'salt': 'D0KI4xHn',
#     'md5': '0cad9837aca32dfb57bbcd515bb69864',
#     'sha1': 'd4c0e519d3135709ccac623fcc56292e0a4009dc',
#     'sha256': '96504b3c97f1ec30bf1abf6fe7d11f69c32419423a48e578425fa414cddfda98'},
#    'dob': {'date': '1989-05-06T11:39:26.589Z', 'age': 35},
#    'registered': {'date': '2009-08-09T17:27:52.529Z', 'age': 15},
#    'phone': '067-93447133',
#    'cell': '0934-351-0508',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/66.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/66.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/66.jpg'},
#    'nat': 'IR'}],
#  'info': {'seed': 'a24adf7e8f73d697',
#   'results': 100,
#   'page': 1,
#   'version': '1.4'}}

# %%
df = pd.json_normalize(data) # decoding the json

# %%
df
# Out:
#                                              results         info.seed  \
# 0  [{'gender': 'female', 'name': {'title': 'Mrs',...  a24adf7e8f73d697
#
#    info.results  info.page info.version
# 0           100          1          1.4

# %%
for i in df['results']: # looking over each record within results column, it is nested json
    print(i)
# Out:
# [{'gender': 'female', 'name': {'title': 'Mrs', 'first': 'Mattie', 'last': 'Reed'}, 'location': {'street': {'number': 1846, 'name': 'Blossom Hill Rd'}, 'city': 'Rockhampton', 'state': 'New South Wales', 'country': 'Australia', 'postcode': 5310, 'coordinates': {'latitude': '-85.0727', 'longitude': '156.8412'}, 'timezone': {'offset': '+10:00', 'description': 'Eastern Australia, Guam, Vladivostok'}}, 'email': 'mattie.reed@example.com', 'login': {'uuid': 'ab7f20b3-83f8-409e-a184-08957eca3b2e', 'username': 'crazybear594', 'password': 'macaroni', 'salt': 'n9GcL4Qf', 'md5': 'f92f78c00ab6275cb2be958e9adfce52', 'sha1': '401f40d8c9814e50cea1ab5dae1b6678b9f64a9d', 'sha256': 'f277ba6b65ef27b4492a44e33ef5402ad78489a9825e8e345b2ccfea722f4119'}, 'dob': {'date': '1976-12-16T04:08:53.186Z', 'age': 47}, 'registered': {'date': '2008-08-04T03:25:11.063Z', 'age': 16}, 'phone': '09-7627-1907', 'cell': '0453-553-546', 'id': {'name': 'TFN', 'value': '082931467'}, 'picture': {'large': 'https://randomuser.me/api/portraits/women/45.jpg', 'medium': 'https://randomuser.me/api/portraits/med/women/45.jpg', 'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/45.jpg'}, 'nat': 'AU'}, {'gender': 'female', 'name': {'title': 'Mrs', 'first': 'Vanity', 'last': 'De Hoogh'}, 'location': {'street': {'number': 1918, 'name': "Achter 'T Ven"}, 'city': 'Walem', 'state': 'Zuid-Holland', 'country': 'Netherlands', 'postcode': '6680 WY', 'coordinates': {'latitude': '-77.4466', 'longitude': '100.5976'}, 'timezone': {'offset': '+11:00', 'description': 'Magadan, Solomon Islands, New Caledonia'}}, 'email': 'vanity.dehoogh@example.com', 'login': {'uuid': '8599587a-0d3f-4627-9b8a-8e29f30ef083', 'username': 'silvercat349', 'password': 'qwerty123', 'salt': 'Fnp2lnkS', 'md5': '50bcc3c0ab466cec10eb33d85b9393c8', 'sha1': '41cc7486fd6a9a812a9d9654fbad5c48d1a6ff10', 'sha256': '200133434f9e24a858ffefae72bb70256f16568d2c1b70ece33ee558c336e49b'}, 'dob': {'date': '1964-11-15T21:50:21.259Z', 'age': 60}, 'registered': {'date': '2004-07-17T08:48:53.024Z', 'age': 20}, 'phone': '(0623) 482904', 'cell': '(06) 25483191', 'id': {'name': 'BSN', 'value': '08685444'}, 'picture': {'large': 'https://randomuser.me/api/portraits/women/43.jpg', 'medium': 'https://randomuser.me/api/portraits/med/women/43.jpg', 'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/43.jpg'}, 'nat': 'NL'}, {'gender': 'female', 'name': {'title': 'Mrs', 'first': 'Mercedes', 'last': 'Cortes'}, 'location': {'street': {'number': 416, 'name': 'Calle de Ferraz'}, 'city': 'Orihuela', 'state': 'Canarias', 'country': 'Spain', 'postcode': 98943, 'coordinates': {'latitude': '-44.9633', 'longitude': '130.3126'}, 'timezone': {'offset': '+6:00', 'description': 'Almaty, Dhaka, Colombo'}}, 'email': 'mercedes.cortes@example.com', 'login': {'uuid': '332bbb24-5171-46ac-a913-5b456d4e16f3', 'username': 'purpleswan117', 'password': '4321', 'salt': '41DrRtFd', 'md5': 'a4d8716cc33f301938eae271c2b08b5f', 'sha1': '9fef11eb1792e3f9f95604ac2e053067b0887820', 'sha256': 'c902f3f48da36ecb1e7a4f7d7a5ed412df0cc186b36076562b95add09b517308'}, 'dob': {'date': '1982-07-02T08:05:59.951Z', 'age': 42}, 'registered': {'date': '2012-05-08T23:27:00.107Z', 'age': 12}, 'phone': '919-456-598', 'cell': '681-289-584', 'id': {'name': 'DNI', 'value': '36233518-X'}, 'picture': {'large': 'https://randomuser.me/api/portraits/women/26.jpg', 'medium': 'https://randomuser.me/api/portraits/med/women/26.jpg', 'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/26.jpg'}, 'nat': 'ES'}, {'gender': 'female', 'name': {'title': 'Mrs', 'first': 'Irma', 'last': 'Luna'}, 'location': {'street': {'number': 6709, 'name': 'Avenida Chihuahua'}, 'city': 'Playa Azul', 'state': 'Nuevo Leon', 'country': 'Mexico', 'postcode': 12661, 'coordinates': {'latitude': '3.5521', 'longitude': '-31.7700'}, 'timezone': {'offset': '+5:45', 'description': 'Kathmandu'}}, 'email': 'irma.luna@example.com', 'login': {'uuid': 'd62e21e9-d876-46aa-90df-4ea26c0792fe', 'username': 'happymeercat136', ' ...

# %%
# Create lists to store the extracted user data
first_name_ls = []
last_name_ls = []
emails_ls = []
genders_ls = []
countries_ls = []
age_ls = []

# %%
# Loop through each user and extract relevant details
for user in data['results']:
    
    email = user.get('email', np.nan) # if no value is present then it will impute None there
    emails_ls.append(email)
    
    first_name = user['name'].get('first', np.nan)
    first_name_ls.append(first_name)
    
    last_name = user['name'].get('last', np.nan)
    last_name_ls.append(last_name)
    
    gender = user.get('gender', np.nan)
    genders_ls.append(gender)
    
    country = user['location'].get('country', np.nan)
    countries_ls.append(country)
    
    age = user['dob'].get('age', np.nan)
    age_ls.append(age)

# %%
df = pd.DataFrame({
    'first_name': first_name_ls,
     'last_name': last_name_ls,
     'Email': emails_ls,
     'Gender': genders_ls,
     'Country': countries_ls,
     'age': age_ls
})

# %%
df.head()
# Out:
#   first_name last_name                        Email  Gender      Country  age
# 0     Mattie      Reed      mattie.reed@example.com  female    Australia   47
# 1     Vanity  De Hoogh   vanity.dehoogh@example.com  female  Netherlands   60
# 2   Mercedes    Cortes  mercedes.cortes@example.com  female        Spain   42
# 3       Irma      Luna        irma.luna@example.com  female       Mexico   26
# 4        Seb   Bloemen      seb.bloemen@example.com    male  Netherlands   66

# %% [markdown]
# ## Load

# %% [markdown]
# create a schema and empty table in sql database before this step:
#
# ```create schema users;```
#
# ```
# create table users.user_details
# (
#
# first_name varchar(500),
# last_name varchar(500),
# Email varchar(500),
# Gender varchar(100),
# Country varchar(500),
# age varchar(100)
# )
# ```

# %%
import mysql.connector
mydb= mysql.connector.connect(host='localhost',user='root',passwd='gunjan', database = 'users')

# %%
cursordb= mydb.cursor()

# %%
for index, row in df.iterrows(): # it will fetch one row at a time
    
    sql_query = "insert into user_details (first_name,last_name,Email,Gender,Country,age) values (%s,%s,%s,%s,%s,%s)"
    cursordb.execute(sql_query, (row['first_name'],row['last_name'],row['Email'],row['Gender'],row['Country'],row['age']))
print("data loaded successfully")
# Out:
# data loaded successfully

# %% [markdown]
# ### Create stored procedure in sql to clean the data

# %% [markdown]
# ```
# DELIMITER //
# -- Provide name to procedure
# CREATE PROCEDURE users.user_data_transformation ()
# BEGIN
# drop table if exists users.user_transformed;
# create table users.user_transformed
# SELECT first_name, last_name, email,
#  SUBSTRING(email, LOCATE('@', email) + 1) AS hostname,
#  gender, country,
# case when age<=18 then 'below 18'
# when age>18 and age<=35 then '18-35'
# when age>35 and age<=65 then '35-65'
# when age>=65 then 'above 65'
# else 'below 18'
# end as age_bucket
#   FROM   users.user_details;
# END //
# DELIMITER ;
# ```

# %%
# calling stored procedure
cursordb.callproc('user_data_transformation')
# Out:
# ()

# %%
mydb.commit() # your changes will be reflected after commit
mydb.close()

# %% [markdown]
# ## now use vscode to create .py file

# %% [markdown]
# **step 1** empty the tables,  truncate the users table and drop the output table of stored procedure
# <br>**step 2** copy the same code in vscode, also add print and time sleep
# <br> **step 3** open the cmd
# <br> **step 4** change directory to D if required using command
# ```D:```
# <br> **step 5** change location cd Documents\DAS\KRPRO_Python\24012024\Projects\ETL
# <br> **step 6** using ```dir``` you can see contents in folder
# <br> **step 7** please install the python and respective libraries, pandas for eg: ```pip install requests```
# <br> **step 8** now run the script using python api_script.py
