# %%
import requests
import pandas as pd

import numpy as np

# %% [markdown]
# ## Extract

# %%
# url for api

url = 'https://randomuser.me/api/'

num_of_users = '?results=100' # we can select the number of user to pull

url = url + num_of_users

print(url)
# Out:
# https://randomuser.me/api/?results=100

# %% [markdown]
# there are two major types of method in api: get and post

# %%
# hitting the api and storing the response

response = requests.get(url)

# %%
# if response is 200 then success, if 500 then internal error, 404 means not found
response
# Out:
# <Response [200]>

# %%
if response.status_code == 200: # to check if we are getting results
    data = response.json() # storing the result

# %%
data
# Out:
# {'results': [{'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Jordan', 'last': 'Cooper'},
#    'location': {'street': {'number': 5968, 'name': 'Pine Hill Road'},
#     'city': 'Upper Hutt',
#     'state': 'Canterbury',
#     'country': 'New Zealand',
#     'postcode': 73563,
#     'coordinates': {'latitude': '53.4953', 'longitude': '-9.3661'},
#     'timezone': {'offset': '+11:00',
#      'description': 'Magadan, Solomon Islands, New Caledonia'}},
#    'email': 'jordan.cooper@example.com',
#    'login': {'uuid': '91f9ad2b-b2c7-4b77-ad2e-fa4d2fab5faf',
#     'username': 'blacktiger984',
#     'password': 'sites',
#     'salt': 'UhWDUBD3',
#     'md5': '970c50a6eda12eef6e2d39a49c62dd25',
#     'sha1': '6f8e50b1d965b54bf0f57f72baed2fb3efe0c529',
#     'sha256': '0b4a8e998e4457e10422e32cb9542a732bf5ce2a15e85e590ada4c093e7c85e7'},
#    'dob': {'date': '1981-08-30T08:11:44.967Z', 'age': 43},
#    'registered': {'date': '2008-03-05T03:44:24.166Z', 'age': 16},
#    'phone': '(196)-739-6917',
#    'cell': '(230)-965-5933',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/82.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/82.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/82.jpg'},
#    'nat': 'NZ'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Alejandra', 'last': 'Navarro'},
#    'location': {'street': {'number': 9821, 'name': 'Avenida del Planetario'},
#     'city': 'Zaragoza',
#     'state': 'Región de Murcia',
#     'country': 'Spain',
#     'postcode': 58896,
#     'coordinates': {'latitude': '-65.2840', 'longitude': '102.2584'},
#     'timezone': {'offset': '-1:00',
#      'description': 'Azores, Cape Verde Islands'}},
#    'email': 'alejandra.navarro@example.com',
#    'login': {'uuid': '450fa88f-455d-40a2-af3f-f82125b26d71',
#     'username': 'beautifulduck872',
#     'password': 'jazz',
#     'salt': 'lhjuRlx2',
#     'md5': '5ad2feb769a820b289a25c6301fa17fb',
#     'sha1': 'ea1f2d8b61a42c0dfa39a5c0e71e894a25ffc634',
#     'sha256': '91f7afe81be516be50b91c3b7f9a0192d09ab27461088312a16ad0bfdd14ed4f'},
#    'dob': {'date': '1974-02-10T23:07:05.446Z', 'age': 50},
#    'registered': {'date': '2011-03-24T04:15:01.456Z', 'age': 13},
#    'phone': '944-647-997',
#    'cell': '616-064-054',
#    'id': {'name': 'DNI', 'value': '34351659-U'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/48.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/48.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/48.jpg'},
#    'nat': 'ES'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Stacy', 'last': 'Johnston'},
#    'location': {'street': {'number': 6811, 'name': 'Saddle Dr'},
#     'city': 'Tulsa',
#     'state': 'Iowa',
#     'country': 'United States',
#     'postcode': 58733,
#     'coordinates': {'latitude': '-52.1532', 'longitude': '129.0020'},
#     'timezone': {'offset': '-9:00', 'description': 'Alaska'}},
#    'email': 'stacy.johnston@example.com',
#    'login': {'uuid': '87877a6b-ffb2-490a-b097-4759298ecfbe',
#     'username': 'organiccat893',
#     'password': 'shemale',
#     'salt': 'UqJhKLnI',
#     'md5': '3113f6a953d46a7496600a60ec83e129',
#     'sha1': 'db37592ebeb5589f96c4b7f128f3a0c59d1f91e5',
#     'sha256': 'd64f78c01f72bd1501a8745f160d036f29b42c161c4653f109be0a32e354a01d'},
#    'dob': {'date': '1986-03-14T02:23:35.113Z', 'age': 38},
#    'registered': {'date': '2009-09-14T09:48:23.699Z', 'age': 15},
#    'phone': '(898) 334-0030',
#    'cell': '(330) 502-0955',
#    'id': {'name': 'SSN', 'value': '016-64-0103'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/73.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/73.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/73.jpg'},
#    'nat': 'US'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'John', 'last': 'Matthews'},
#    'location': {'street': {'number': 2863, 'name': 'The Crescent'},
#     'city': 'Kilcoole',
#     'state': 'South Dublin',
#     'country': 'Ireland',
#     'postcode': 95591,
#     'coordinates': {'latitude': '-5.0675', 'longitude': '-63.5333'},
#     'timezone': {'offset': '-3:30', 'description': 'Newfoundland'}},
#    'email': 'john.matthews@example.com',
#    'login': {'uuid': '1abe48c4-9199-438c-91eb-5ccfd2560041',
#     'username': 'redzebra849',
#     'password': 'green1',
#     'salt': 'uMano8Fp',
#     'md5': '5db079360594769e3bc6c3634a891817',
#     'sha1': '149d52fd4e87d6b9661c7b32d061326a23142c3e',
#     'sha256': '8dc8b547ca0b1a5750cd2fb74475cf84264be8ebeb254bbe8ca703603bfb56a8'},
#    'dob': {'date': '1958-05-18T04:07:32.058Z', 'age': 66},
#    'registered': {'date': '2021-02-14T09:15:28.282Z', 'age': 3},
#    'phone': '051-589-9835',
#    'cell': '081-239-0183',
#    'id': {'name': 'PPS', 'value': '9693807T'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/92.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/92.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/92.jpg'},
#    'nat': 'IE'},
#   {'gender': 'female',
#    'name': {'title': 'Ms', 'first': 'Naomi', 'last': 'Afzal'},
#    'location': {'street': {'number': 4381, 'name': 'Danmarks gate'},
#     'city': 'Blakstad',
#     'state': 'Møre og Romsdal',
#     'country': 'Norway',
#     'postcode': '0664',
#     'coordinates': {'latitude': '-60.6490', 'longitude': '-49.3184'},
#     'timezone': {'offset': '+7:00', 'description': 'Bangkok, Hanoi, Jakarta'}},
#    'email': 'naomi.afzal@example.com',
#    'login': {'uuid': '16130f89-02aa-4702-8571-8954d7df5903',
#     'username': 'sadleopard568',
#     'password': 'houston',
#     'salt': 'zcf9j2kX',
#     'md5': '0f80d04aafa25efbb90569d48c18b7b6',
#     'sha1': '97e76de4dfc9a561482e5a4739310afefcb92205',
#     'sha256': '8e36a47d394c185d5b92585e347229ff87300a132aec1ab6e4805be0b5ec36e4'},
#    'dob': {'date': '1966-01-23T03:24:58.783Z', 'age': 58},
#    'registered': {'date': '2011-07-11T14:52:04.112Z', 'age': 13},
#    'phone': '30671397',
#    'cell': '90355022',
#    'id': {'name': 'FN', 'value': '23016614432'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/9.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/9.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/9.jpg'},
#    'nat': 'NO'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Djoko', 'last': 'Tomašević'},
#    'location': {'street': {'number': 7358, 'name': 'Lene Ljubić'},
#     'city': 'Lapovo',
#     'state': 'Zaječar',
#     'country': 'Serbia',
#     'postcode': 72652,
#     'coordinates': {'latitude': '-49.1059', 'longitude': '168.2865'},
#     'timezone': {'offset': '+8:00',
#      'description': 'Beijing, Perth, Singapore, Hong Kong'}},
#    'email': 'djoko.tomasevic@example.com',
#    'login': {'uuid': '846afd3e-ea8c-4ffd-a945-f02d5fbe5d1b',
#     'username': 'redpeacock555',
#     'password': 'forum',
#     'salt': 'QJOE8DPU',
#     'md5': '9f09e62b858f27d730fdef71aed09494',
#     'sha1': '277104c3bc6bc4b0d3f5492a316cb7c547777f65',
#     'sha256': 'f1a761b81b46d0f5a40377f57467f871df887aeb8fb04b9dc1916b775f15d1a3'},
#    'dob': {'date': '1958-08-31T01:03:12.662Z', 'age': 66},
#    'registered': {'date': '2009-05-06T04:03:41.568Z', 'age': 15},
#    'phone': '012-3866-681',
#    'cell': '060-3150-405',
#    'id': {'name': 'SID', 'value': '929456252'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/31.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/31.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/31.jpg'},
#    'nat': 'RS'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Eilev', 'last': 'Larsen'},
#    'location': {'street': {'number': 4149, 'name': 'Dannevigsveien'},
#     'city': 'Stokke',
#     'state': 'Nord-Trøndelag',
#     'country': 'Norway',
#     'postcode': '3427',
#     'coordinates': {'latitude': '44.8345', 'longitude': '45.0174'},
#     'timezone': {'offset': '-9:00', 'description': 'Alaska'}},
#    'email': 'eilev.larsen@example.com',
#    'login': {'uuid': 'b0dc7206-e601-4f2d-ac7b-8867140ab25f',
#     'username': 'angrytiger128',
#     'password': 'coolman',
#     'salt': 'lMXF2yAF',
#     'md5': '04e79ba7824ec44177a8ba2a64213f2d',
#     'sha1': 'cb448ae84d5dc628e57be6ab78b4d15864c678cc',
#     'sha256': '9c23f5e0b698348e4ec0d7b23750f45f0842ae490d04e2a4ea16f18e08cde8f1'},
#    'dob': {'date': '1960-12-25T06:16:11.590Z', 'age': 63},
#    'registered': {'date': '2015-03-16T11:58:21.928Z', 'age': 9},
#    'phone': '27484080',
#    'cell': '49175586',
#    'id': {'name': 'FN', 'value': '25126048796'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/15.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/15.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/15.jpg'},
#    'nat': 'NO'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Vernon', 'last': 'Stone'},
#    'location': {'street': {'number': 5800, 'name': 'Mockingbird Ln'},
#     'city': 'Philadelphia',
#     'state': 'Ohio',
#     'country': 'United States',
#     'postcode': 78369,
#     'coordinates': {'latitude': '44.9115', 'longitude': '45.4245'},
#     'timezone': {'offset': '+3:30', 'description': 'Tehran'}},
#    'email': 'vernon.stone@example.com',
#    'login': {'uuid': '0699133b-1d63-4ddb-a6fb-a9a7f7ab5ac8',
#     'username': 'yellowmouse829',
#     'password': 'search',
#     'salt': 'd6LY9jV1',
#     'md5': '60634ae51be78e5aae329b808c8c8a02',
#     'sha1': '1f3483b411affe380b42e7b6ac267320c9742178',
#     'sha256': 'e4ba53f7bdc7220b2b37baa8f807d0eef2ddce0ffd43d419fc8dd0cf7db415ba'},
#    'dob': {'date': '1978-04-08T07:25:23.675Z', 'age': 46},
#    'registered': {'date': '2006-04-26T01:21:55.854Z', 'age': 18},
#    'phone': '(914) 857-1019',
#    'cell': '(746) 816-8455',
#    'id': {'name': 'SSN', 'value': '840-51-1386'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/87.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/87.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/87.jpg'},
#    'nat': 'US'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Fernando', 'last': 'Collins'},
#    'location': {'street': {'number': 9599, 'name': 'Hunters Creek Dr'},
#     'city': 'Wagga Wagga',
#     'state': 'Queensland',
#     'country': 'Australia',
#     'postcode': 3880,
#     'coordinates': {'latitude': '-45.5579', 'longitude': '-52.8325'},
#     'timezone': {'offset': '+5:45', 'description': 'Kathmandu'}},
#    'email': 'fernando.collins@example.com',
#    'login': {'uuid': '5546da9a-d205-4181-b08f-3f69a383b037',
#     'username': 'bigmouse448',
#     'password': 'kissme',
#     'salt': 'PCpuNcuU',
#     'md5': '3dc746e8f85c007aa4abf025ad0bf354',
#     'sha1': 'd28cc73de7fe95bc6d94cbea3ed8533a0b37ed59',
#     'sha256': '80e0b97d71c025a4d26983a2772c92919f276be1d51b12acd67d5fefd9a2e6de'},
#    'dob': {'date': '1993-08-05T01:28:48.820Z', 'age': 31},
#    'registered': {'date': '2005-10-19T15:39:34.545Z', 'age': 18},
#    'phone': '08-0380-9492',
#    'cell': '0492-663-175',
#    'id': {'name': 'TFN', 'value': '445629564'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/95.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/95.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/95.jpg'},
#    'nat': 'AU'},
#   {'gender': 'female',
#    'name': {'title': 'Mademoiselle', 'first': 'Gisèle', 'last': 'Durand'},
#    'location': {'street': {'number': 3758, 'name': 'Grande Rue'},
#     'city': 'Inkwil',
#     'state': 'Nidwalden',
#     'country': 'Switzerland',
#     'postcode': 2699,
#     'coordinates': {'latitude': '-67.6632', 'longitude': '-30.6294'},
#     'timezone': {'offset': '+2:00',
#      'description': 'Kaliningrad, South Africa'}},
#    'email': 'gisele.durand@example.com',
#    'login': {'uuid': '2c632ac8-d668-440e-84a2-0b7e61d13e2b',
#     'username': 'whitezebra305',
#     'password': 'tech',
#     'salt': 'UfF8aCwP',
#     'md5': '9028244675ea3f76c04bcf431afb1f42',
#     'sha1': '5bdad29a09b1f300973036d904c36ff9e0b261b4',
#     'sha256': '166fd6b0718d04ab7f3aea56373f6acdb8f87d151dbefb256354ce667226dae8'},
#    'dob': {'date': '1967-01-22T20:21:47.604Z', 'age': 57},
#    'registered': {'date': '2019-09-27T07:08:41.474Z', 'age': 4},
#    'phone': '079 562 58 04',
#    'cell': '078 723 55 77',
#    'id': {'name': 'AVS', 'value': '756.0408.3108.27'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/24.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/24.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/24.jpg'},
#    'nat': 'CH'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Tonje', 'last': 'Zimmermann'},
#    'location': {'street': {'number': 8875, 'name': 'Sehesteds gate'},
#     'city': 'Steinshamn',
#     'state': 'Telemark',
#     'country': 'Norway',
#     'postcode': '4017',
#     'coordinates': {'latitude': '14.2109', 'longitude': '13.3160'},
#     'timezone': {'offset': '+6:00', 'description': 'Almaty, Dhaka, Colombo'}},
#    'email': 'tonje.zimmermann@example.com',
#    'login': {'uuid': 'da005f7f-e998-4aac-8e9d-f2cdcfac93ee',
#     'username': 'yellowsnake234',
#     'password': 'cuan',
#     'salt': '81klT8OZ',
#     'md5': '58c0f9f894e44f83b2dde32503e2d995',
#     'sha1': '23396b4bb999ca6bbd967c9414eb1a37b495003c',
#     'sha256': '60f37d4a03e9925bc216a5eb86ffb9005616a736ae126df86d64b558fefdcef6'},
#    'dob': {'date': '1951-03-23T21:06:14.201Z', 'age': 73},
#    'registered': {'date': '2013-10-10T05:00:02.882Z', 'age': 10},
#    'phone': '79728787',
#    'cell': '44619839',
#    'id': {'name': 'FN', 'value': '23035136002'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/61.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/61.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/61.jpg'},
#    'nat': 'NO'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Billy', 'last': 'Adams'},
#    'location': {'street': {'number': 1537, 'name': 'Park Avenue'},
#     'city': 'Killarney',
#     'state': 'Offaly',
#     'country': 'Ireland',
#     'postcode': 80703,
#     'coordinates': {'latitude': '-55.8286', 'longitude': '-31.2193'},
#     'timezone': {'offset': '+9:30', 'description': 'Adelaide, Darwin'}},
#    'email': 'billy.adams@example.com',
#    'login': {'uuid': 'c8b202eb-6ac2-49d7-88d6-08225ea0252c',
#     'username': 'goldencat765',
#     'password': 'fmale',
#     'salt': 'gdz0q8Jl',
#     'md5': '781e355dea9cac68619814c1bb84d7cf',
#     'sha1': 'e62c04e7477f1ea13d2c291c26627123e401f24a',
#     'sha256': 'c0ba9b2e364cc58369bf08434f6bd95fdccc1c71bf539f452269381cbaaacbb1'},
#    'dob': {'date': '1977-02-14T04:40:00.591Z', 'age': 47},
#    'registered': {'date': '2021-03-21T15:24:16.525Z', 'age': 3},
#    'phone': '031-770-1697',
#    'cell': '081-231-3969',
#    'id': {'name': 'PPS', 'value': '4320447T'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/92.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/92.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/92.jpg'},
#    'nat': 'IE'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Kristian', 'last': 'Eriksrud'},
#    'location': {'street': {'number': 343, 'name': 'Kopperuds vei'},
#     'city': 'Alternes',
#     'state': 'Oppland',
#     'country': 'Norway',
#     'postcode': '1954',
#     'coordinates': {'latitude': '82.7975', 'longitude': '-35.9912'},
#     'timezone': {'offset': '+1:00',
#      'description': 'Brussels, Copenhagen, Madrid, Paris'}},
#    'email': 'kristian.eriksrud@example.com',
#    'login': {'uuid': 'e69a735a-05b8-41a6-92fd-15d1f7f3f4ba',
#     'username': 'lazygorilla393',
#     'password': 'link',
#     'salt': 'Zf8KnEyX',
#     'md5': 'f720050fcb7885adb3a86fd7cf444935',
#     'sha1': '76e17cb278b0258e8f5e2317514522a652d3c2fb',
#     'sha256': '82597f2c5d15dcdade6f8233572cabd9f5b8a319ad84aa711de0c683f04def65'},
#    'dob': {'date': '1980-02-26T06:18:44.406Z', 'age': 44},
#    'registered': {'date': '2013-08-09T10:15:41.298Z', 'age': 11},
#    'phone': '58169989',
#    'cell': '97218950',
#    'id': {'name': 'FN', 'value': '26028000315'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/54.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/54.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/54.jpg'},
#    'nat': 'NO'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Neha', 'last': 'Bansal'},
#    'location': {'street': {'number': 2833, 'name': 'Swargate'},
#     'city': 'Chinsurah',
#     'state': 'Bihar',
#     'country': 'India',
#     'postcode': 79107,
#     'coordinates': {'latitude': '-34.5864', 'longitude': '-110.7661'},
#     'timezone': {'offset': '+3:00',
#      'description': 'Baghdad, Riyadh, Moscow, St. Petersburg'}},
#    'email': 'neha.bansal@example.com',
#    'login': {'uuid': 'b8778a4e-8976-42d5-8486-268eb18f075a',
#     'username': 'lazyladybug855',
#     'password': 'coolio',
#     'salt': 'PiIJCxJv',
#     'md5': '72406db249bf19d00501f0c7e9b518cf',
#     'sha1': 'a49a647e3c6c167ba9ad6409dce550df497d54e0',
#     'sha256': 'd9a6ce9e0adbde3f9f41da6ae751c9b653aab77a23b72362244336391f6d69d2'},
#    'dob': {'date': '1947-11-03T10:18:08.215Z', 'age': 76},
#    'registered': {'date': '2007-01-08T23:02:31.993Z', 'age': 17},
#    'phone': '9875686254',
#    'cell': '9056399242',
#    'id': {'name': 'UIDAI', 'value': '052239369848'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/14.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/14.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/14.jpg'},
#    'nat': 'IN'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'رضا', 'last': 'صدر'},
#    'location': {'street': {'number': 517, 'name': 'پاسداران'},
#     'city': 'قزوین',
#     'state': 'هرمزگان',
#     'country': 'Iran',
#     'postcode': 32307,
#     'coordinates': {'latitude': '69.2567', 'longitude': '161.5138'},
#     'timezone': {'offset': '-3:00',
#      'description': 'Brazil, Buenos Aires, Georgetown'}},
#    'email': 'rd.sdr@example.com',
#    'login': {'uuid': 'f36d413e-8a38-4d07-9c45-98bc071e520d',
#     'username': 'silvergorilla795',
#     'password': 'weaver',
#     'salt': 'YBi89Vum',
#     'md5': 'f63c128632cb0362c17c3033fb795d64',
#     'sha1': '289b305af9149db6695520accab042773e8992df',
#     'sha256': '51b9b80d4b25c9ee3f32fe3d22259a6d03434517adbb6384f55d91aa99c65143'},
#    'dob': {'date': '1985-01-07T03:25:44.689Z', 'age': 39},
#    'registered': {'date': '2017-03-23T05:34:49.184Z', 'age': 7},
#    'phone': '097-89593226',
#    'cell': '0910-960-0997',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/20.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/20.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/20.jpg'},
#    'nat': 'IR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Jarmo', 'last': 'Yildirim'},
#    'location': {'street': {'number': 2723, 'name': 'Hertstraat'},
#     'city': 'Varsselder',
#     'state': 'Noord-Holland',
#     'country': 'Netherlands',
#     'postcode': '0510 OI',
#     'coordinates': {'latitude': '-52.1503', 'longitude': '100.8831'},
#     'timezone': {'offset': '-3:00',
#      'description': 'Brazil, Buenos Aires, Georgetown'}},
#    'email': 'jarmo.yildirim@example.com',
#    'login': {'uuid': 'caef8ceb-cc5f-4d23-bfad-4fd219abfc3d',
#     'username': 'organicfrog305',
#     'password': 'slayer',
#     'salt': 'lk5ArU9n',
#     'md5': '3a0ba3f4af4e815b5c3e5f2f9df34af6',
#     'sha1': '4be6c9ae0dbda706384e7f0de139b560d2179489',
#     'sha256': '4203d73fe23b5591a66933d90629be135d256781c06227cd7279a77a545f15e4'},
#    'dob': {'date': '1975-03-09T20:59:21.208Z', 'age': 49},
#    'registered': {'date': '2008-02-01T07:02:17.211Z', 'age': 16},
#    'phone': '(0774) 129819',
#    'cell': '(06) 31485148',
#    'id': {'name': 'BSN', 'value': '53213485'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/3.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/3.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/3.jpg'},
#    'nat': 'NL'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Zhivoslav', 'last': 'Bovkun'},
#    'location': {'street': {'number': 6917, 'name': 'Novopecherskiy provulok'},
#     'city': 'Kiliya',
#     'state': 'Vinnicka',
#     'country': 'Ukraine',
#     'postcode': 41281,
#     'coordinates': {'latitude': '44.3975', 'longitude': '115.2588'},
#     'timezone': {'offset': '-11:00', 'description': 'Midway Island, Samoa'}},
#    'email': 'zhivoslav.bovkun@example.com',
#    'login': {'uuid': 'c06a1fc5-f467-4710-a297-bc116f4f9255',
#     'username': 'blackfish872',
#     'password': 'banner',
#     'salt': 'AAzsilbj',
#     'md5': 'bc9081cf09533c03319873a82664bc8a',
#     'sha1': '78f70ebb61ebfef44606b8d89bd4b7de66636718',
#     'sha256': '74da601a0ea4773cbef7eb5e5820e4418ad6d625723494e66fdf641496380f60'},
#    'dob': {'date': '1999-01-01T19:08:07.751Z', 'age': 25},
#    'registered': {'date': '2012-07-31T15:29:29.793Z', 'age': 12},
#    'phone': '(099) C42-2359',
#    'cell': '(066) S44-9470',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/89.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/89.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/89.jpg'},
#    'nat': 'UA'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Aurora', 'last': 'Santos'},
#    'location': {'street': {'number': 5240, 'name': 'Calle de Argumosa'},
#     'city': 'Toledo',
#     'state': 'Navarra',
#     'country': 'Spain',
#     'postcode': 90396,
#     'coordinates': {'latitude': '-64.2118', 'longitude': '86.3994'},
#     'timezone': {'offset': '-9:00', 'description': 'Alaska'}},
#    'email': 'aurora.santos@example.com',
#    'login': {'uuid': '9fe6cb12-9fb3-4526-aaf7-53167cc58270',
#     'username': 'sadgorilla315',
#     'password': 'kangaroo',
#     'salt': 'o4CoL22o',
#     'md5': 'fc57e29533290ef6780d9dfbbaf48c2c',
#     'sha1': '408310b31b5944197377b3e30b5a6307e97b7964',
#     'sha256': '80b0d9abbabbd079051158ad0b4ff2c29cf49045abbd972e82a0617f4019bdb0'},
#    'dob': {'date': '1961-10-29T00:42:02.201Z', 'age': 62},
#    'registered': {'date': '2014-12-25T22:17:30.894Z', 'age': 9},
#    'phone': '908-477-072',
#    'cell': '653-278-833',
#    'id': {'name': 'DNI', 'value': '68736373-Q'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/64.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/64.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/64.jpg'},
#    'nat': 'ES'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Seppe', 'last': 'Tuithof'},
#    'location': {'street': {'number': 4825, 'name': 'Blomikkers'},
#     'city': 'Heide',
#     'state': 'Groningen',
#     'country': 'Netherlands',
#     'postcode': '9527 IY',
#     'coordinates': {'latitude': '-8.1239', 'longitude': '-178.0044'},
#     'timezone': {'offset': '-1:00',
#      'description': 'Azores, Cape Verde Islands'}},
#    'email': 'seppe.tuithof@example.com',
#    'login': {'uuid': '85d1f937-6c87-465a-985e-19efdfab42de',
#     'username': 'brownzebra987',
#     'password': 'savage',
#     'salt': 'kdECG8hO',
#     'md5': 'e1359b122871a15676ff1e201ea3e341',
#     'sha1': 'a8d9469b628c82c205c32175b2f95c93773c99f1',
#     'sha256': 'b025938360abbf137f0fd4761468cd0bdc03c96ac6cecd87bf3d9b77fd2617b0'},
#    'dob': {'date': '1995-06-05T07:15:51.431Z', 'age': 29},
#    'registered': {'date': '2005-09-28T14:29:53.411Z', 'age': 18},
#    'phone': '(019) 9852018',
#    'cell': '(06) 63867499',
#    'id': {'name': 'BSN', 'value': '47300571'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/34.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/34.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/34.jpg'},
#    'nat': 'NL'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Ruby', 'last': 'Benavides'},
#    'location': {'street': {'number': 7634, 'name': 'Ampliación Zacatecas'},
#     'city': 'Rodeo',
#     'state': 'Jalisco',
#     'country': 'Mexico',
#     'postcode': 49260,
#     'coordinates': {'latitude': '11.9311', 'longitude': '-173.7014'},
#     'timezone': {'offset': '-4:00',
#      'description': 'Atlantic Time (Canada), Caracas, La Paz'}},
#    'email': 'ruby.benavides@example.com',
#    'login': {'uuid': 'f38b7108-4e32-4ca2-8976-95477d032fdc',
#     'username': 'purplebutterfly782',
#     'password': 'janine',
#     'salt': 'SUVc1eIS',
#     'md5': '35d1e3b73a78fb86ea34835c0ef0f301',
#     'sha1': '6753d8f0807c63638744b8c93991f7c355d3a7b5',
#     'sha256': 'b94d8d06356bc1d11a385337bd4067d26713e0d558301efe3de463cbaa719741'},
#    'dob': {'date': '1960-12-27T07:08:48.683Z', 'age': 63},
#    'registered': {'date': '2020-08-10T16:25:26.616Z', 'age': 4},
#    'phone': '(614) 746 2049',
#    'cell': '(694) 164 2522',
#    'id': {'name': 'NSS', 'value': '09 72 39 4458 0'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/32.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/32.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/32.jpg'},
#    'nat': 'MX'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Fatih', 'last': 'Aydan'},
#    'location': {'street': {'number': 9121, 'name': 'Kushimoto Sk'},
#     'city': 'Kırıkkale',
#     'state': 'Hatay',
#     'country': 'Turkey',
#     'postcode': 85685,
#     'coordinates': {'latitude': '7.6148', 'longitude': '64.0713'},
#     'timezone': {'offset': '0:00',
#      'description': 'Western Europe Time, London, Lisbon, Casablanca'}},
#    'email': 'fatih.aydan@example.com',
#    'login': {'uuid': 'ea487e08-a6ef-4473-8843-5e59ed7d9666',
#     'username': 'smallduck788',
#     'password': 'moonshin',
#     'salt': 'YSaunewq',
#     'md5': '6dcbbf2ea51c2d0e35f54e1e375394fd',
#     'sha1': 'ccede39b8f987446f3ef89a40a15c0342411e6e4',
#     'sha256': '353756dc18e7796f468b34847ead276f0f689b098598824600bfa47def39043c'},
#    'dob': {'date': '2000-06-18T00:45:08.711Z', 'age': 24},
#    'registered': {'date': '2014-08-08T07:57:07.574Z', 'age': 10},
#    'phone': '(907)-544-4087',
#    'cell': '(849)-055-3315',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/58.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/58.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/58.jpg'},
#    'nat': 'TR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Dilermando', 'last': 'Rocha'},
#    'location': {'street': {'number': 655, 'name': 'Avenida da Legalidade'},
#     'city': 'Ribeirão Preto',
#     'state': 'Amazonas',
#     'country': 'Brazil',
#     'postcode': 61548,
#     'coordinates': {'latitude': '-25.5135', 'longitude': '-161.4089'},
#     'timezone': {'offset': '+1:00',
#      'description': 'Brussels, Copenhagen, Madrid, Paris'}},
#    'email': 'dilermando.rocha@example.com',
#    'login': {'uuid': 'fbb3d72f-fc53-4fc6-8bb3-ebdf8f544b20',
#     'username': 'orangepanda512',
#     'password': 'huai',
#     'salt': 'FiGTKTpN',
#     'md5': '75417b8c8749f792195c240157aef75a',
#     'sha1': '9043fad75345ab2d346eb69f18b4c6dc4c4bb5ab',
#     'sha256': '0c48ca3ae4c5886541585edb4486af0bd012fbbc883dbf9f7aacfa58153cda32'},
#    'dob': {'date': '1995-01-19T05:09:43.540Z', 'age': 29},
#    'registered': {'date': '2015-06-25T10:33:18.234Z', 'age': 9},
#    'phone': '(00) 6071-5677',
#    'cell': '(36) 2102-0438',
#    'id': {'name': 'CPF', 'value': '552.727.888-68'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/5.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/5.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/5.jpg'},
#    'nat': 'BR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Ray', 'last': 'Ray'},
#    'location': {'street': {'number': 2942, 'name': 'South Street'},
#     'city': 'Ely',
#     'state': 'South Glamorgan',
#     'country': 'United Kingdom',
#     'postcode': 'WK8 5HY',
#     'coordinates': {'latitude': '83.9360', 'longitude': '47.9783'},
#     'timezone': {'offset': '-10:00', 'description': 'Hawaii'}},
#    'email': 'ray.ray@example.com',
#    'login': {'uuid': '00ffcb06-f54b-4dab-a2e6-4bf3d9538405',
#     'username': 'happyelephant237',
#     'password': 'bonjour',
#     'salt': 'mEeEISop',
#     'md5': '03afee5e3b6a8eb7a43201d1118e5c9f',
#     'sha1': '2730ef3650ff0b653aba603fa4e88cff160d30d5',
#     'sha256': 'a7001cd03d3f61b1813f479d7bd679d3f0092fcfc4d9dbcdc2951c27b80fc7b5'},
#    'dob': {'date': '1987-04-09T09:11:47.387Z', 'age': 37},
#    'registered': {'date': '2018-03-21T21:48:50.738Z', 'age': 6},
#    'phone': '017683 24974',
#    'cell': '07672 690246',
#    'id': {'name': 'NINO', 'value': 'BB 91 96 22 K'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/50.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/50.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/50.jpg'},
#    'nat': 'GB'},
#   {'gender': 'female',
#    'name': {'title': 'Madame', 'first': 'Charlotte', 'last': 'Robin'},
#    'location': {'street': {'number': 2256, 'name': 'Route de Genas'},
#     'city': 'Dietwil',
#     'state': 'Fribourg',
#     'country': 'Switzerland',
#     'postcode': 3503,
#     'coordinates': {'latitude': '-11.9534', 'longitude': '-7.4289'},
#     'timezone': {'offset': '+7:00', 'description': 'Bangkok, Hanoi, Jakarta'}},
#    'email': 'charlotte.robin@example.com',
#    'login': {'uuid': '7b8127bb-723e-4d2e-a526-d827e854266d',
#     'username': 'sadfish789',
#     'password': 'dharma',
#     'salt': 'uifljVZl',
#     'md5': 'b9271f648b516eaca9284b7611410a7e',
#     'sha1': 'bf1c18e53d29fb85b7c2be7abb05eab664373954',
#     'sha256': '606a6c6dfab46c15727eb1e375b09cef61208100d71f326bad9914fed35683ff'},
#    'dob': {'date': '1957-10-27T09:19:37.805Z', 'age': 66},
#    'registered': {'date': '2006-07-06T09:41:47.837Z', 'age': 18},
#    'phone': '077 477 55 65',
#    'cell': '077 714 76 89',
#    'id': {'name': 'AVS', 'value': '756.4944.5323.09'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/9.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/9.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/9.jpg'},
#    'nat': 'CH'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Signe', 'last': 'Nielsen'},
#    'location': {'street': {'number': 7920, 'name': 'Nørrebro'},
#     'city': 'Frederiksberg',
#     'state': 'Midtjylland',
#     'country': 'Denmark',
#     'postcode': 62487,
#     'coordinates': {'latitude': '17.5972', 'longitude': '-175.3433'},
#     'timezone': {'offset': '-8:00',
#      'description': 'Pacific Time (US & Canada)'}},
#    'email': 'signe.nielsen@example.com',
#    'login': {'uuid': '82185f06-10ba-4605-a664-2302124df8ee',
#     'username': 'organicbutterfly158',
#     'password': 'mirage',
#     'salt': 'ZdX2XgcZ',
#     'md5': '5b4e0c7aa780d068d03b8269b343296d',
#     'sha1': '353a02e8c6016a0cd91a4ca0e1e8dd41ac1df241',
#     'sha256': 'afc8a7e9c122e962476998653b56cc89ff0a2f07ea57bc10e3b598d83fb767a1'},
#    'dob': {'date': '1964-05-12T11:31:06.211Z', 'age': 60},
#    'registered': {'date': '2009-12-15T16:34:49.883Z', 'age': 14},
#    'phone': '20798451',
#    'cell': '19180497',
#    'id': {'name': 'CPR', 'value': '120564-8143'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/29.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/29.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/29.jpg'},
#    'nat': 'DK'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Robert', 'last': 'Welch'},
#    'location': {'street': {'number': 1591, 'name': 'West Street'},
#     'city': 'Londonderry',
#     'state': 'Durham',
#     'country': 'United Kingdom',
#     'postcode': 'F5 3GP',
#     'coordinates': {'latitude': '-71.9138', 'longitude': '-2.2583'},
#     'timezone': {'offset': '+5:00',
#      'description': 'Ekaterinburg, Islamabad, Karachi, Tashkent'}},
#    'email': 'robert.welch@example.com',
#    'login': {'uuid': '4468f1b7-6f7c-414a-ad11-85dde3e739dd',
#     'username': 'yellowduck136',
#     'password': 'allsop',
#     'salt': 'vsKuvGhb',
#     'md5': 'a9c254f1eaee826584144875dde91d34',
#     'sha1': '8a95ce675e16854ba24e9bc0a263a110e3c27f10',
#     'sha256': '16a44d792bb5d4cbc722cb2c1003cb7230420514fa684c89b6186fe8cdd04d0f'},
#    'dob': {'date': '1944-10-30T07:19:18.408Z', 'age': 79},
#    'registered': {'date': '2020-09-30T14:11:49.175Z', 'age': 3},
#    'phone': '017683 09703',
#    'cell': '07380 934033',
#    'id': {'name': 'NINO', 'value': 'SS 32 00 04 Y'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/79.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/79.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/79.jpg'},
#    'nat': 'GB'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Olindo', 'last': 'da Cruz'},
#    'location': {'street': {'number': 7207, 'name': 'Rua Belo Horizonte '},
#     'city': 'Cuiabá',
#     'state': 'São Paulo',
#     'country': 'Brazil',
#     'postcode': 44118,
#     'coordinates': {'latitude': '-46.7457', 'longitude': '0.6040'},
#     'timezone': {'offset': '+5:00',
#      'description': 'Ekaterinburg, Islamabad, Karachi, Tashkent'}},
#    'email': 'olindo.dacruz@example.com',
#    'login': {'uuid': 'b634aa0e-7bb0-4c39-94be-d45adc6a5b6a',
#     'username': 'bigbear286',
#     'password': 'termite',
#     'salt': 'YUKk37n8',
#     'md5': 'f33cb592a385505483fce2d2ff02be34',
#     'sha1': '688c67994ea654a4686261b2ef1321ec401219f5',
#     'sha256': '4a92f12181460b2d4088b70ddb3941fedb4e00117f0c2fbbd05c248a5c395b3d'},
#    'dob': {'date': '2000-05-17T03:04:26.803Z', 'age': 24},
#    'registered': {'date': '2017-04-05T18:38:13.557Z', 'age': 7},
#    'phone': '(75) 8435-7509',
#    'cell': '(57) 9149-3708',
#    'id': {'name': 'CPF', 'value': '659.180.122-97'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/68.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/68.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/68.jpg'},
#    'nat': 'BR'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Belén', 'last': 'Soler'},
#    'location': {'street': {'number': 5997, 'name': 'Calle Nebrija'},
#     'city': 'Ferrol',
#     'state': 'Castilla la Mancha',
#     'country': 'Spain',
#     'postcode': 41356,
#     'coordinates': {'latitude': '36.8188', 'longitude': '-106.1930'},
#     'timezone': {'offset': '-12:00', 'description': 'Eniwetok, Kwajalein'}},
#    'email': 'belen.soler@example.com',
#    'login': {'uuid': 'db67255c-2077-48f1-ac3f-fe252fed8402',
#     'username': 'whiteladybug911',
#     'password': 'trixie',
#     'salt': 'fQa3IHME',
#     'md5': 'eab3766b3628bb78b76bdb9c6b7e9272',
#     'sha1': '9ccf62e2be57461521aed5804b1b194dea111cf9',
#     'sha256': 'b35d56459e3a5dacb0eae63b6ebcaf61b28b71a5d3f28a236cdd8f35738e2432'},
#    'dob': {'date': '1990-08-23T14:21:06.474Z', 'age': 34},
#    'registered': {'date': '2011-06-19T03:20:42.422Z', 'age': 13},
#    'phone': '993-904-982',
#    'cell': '616-996-915',
#    'id': {'name': 'DNI', 'value': '63931197-F'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/5.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/5.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/5.jpg'},
#    'nat': 'ES'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Shannon', 'last': 'Hansen'},
#    'location': {'street': {'number': 6402, 'name': 'Camden Ave'},
#     'city': 'Charlotte',
#     'state': 'Arizona',
#     'country': 'United States',
#     'postcode': 22972,
#     'coordinates': {'latitude': '61.8604', 'longitude': '-94.7493'},
#     'timezone': {'offset': '+9:00',
#      'description': 'Tokyo, Seoul, Osaka, Sapporo, Yakutsk'}},
#    'email': 'shannon.hansen@example.com',
#    'login': {'uuid': 'a6792a13-3a5d-4ab6-af7b-5018b2e84b5f',
#     'username': 'goldenelephant497',
#     'password': 'believe',
#     'salt': 'wTjZEW1V',
#     'md5': '7ab5a5f662c08d7d580d98fd78659222',
#     'sha1': '0e16b86bdf097f4ef4638099b5770f2e12f53acd',
#     'sha256': 'f29cc67022b17173c6a69ee07657e45b3b6e98f1e7162b65c8ebede2afc26d5f'},
#    'dob': {'date': '1964-09-21T02:17:22.436Z', 'age': 59},
#    'registered': {'date': '2020-08-24T10:58:41.869Z', 'age': 4},
#    'phone': '(985) 877-9129',
#    'cell': '(460) 617-9410',
#    'id': {'name': 'SSN', 'value': '286-44-3475'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/89.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/89.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/89.jpg'},
#    'nat': 'US'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Ullrich', 'last': 'Stroh'},
#    'location': {'street': {'number': 167, 'name': 'Rosenstraße'},
#     'city': 'Büdingen',
#     'state': 'Sachsen-Anhalt',
#     'country': 'Germany',
#     'postcode': 42586,
#     'coordinates': {'latitude': '27.3653', 'longitude': '42.1676'},
#     'timezone': {'offset': '-10:00', 'description': 'Hawaii'}},
#    'email': 'ullrich.stroh@example.com',
#    'login': {'uuid': 'd144c0a7-6bcc-40d1-8b79-1c4e517c6a31',
#     'username': 'tinypanda667',
#     'password': 'message',
#     'salt': 'AHPUT8JQ',
#     'md5': 'a568e41e3feb2ea7b7e78e8bfe0d75cf',
#     'sha1': 'f7f0a9a6ec92d76b22dd4429c23f16cccd94d5be',
#     'sha256': '7ee18615aec3211ce5eed2e7c7d7347c7520d179925a78134a030d7950853014'},
#    'dob': {'date': '1949-07-07T16:07:30.288Z', 'age': 75},
#    'registered': {'date': '2008-09-16T16:01:02.895Z', 'age': 15},
#    'phone': '0909-0840202',
#    'cell': '0174-7606292',
#    'id': {'name': 'SVNR', 'value': '43 070749 S 355'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/42.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/42.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/42.jpg'},
#    'nat': 'DE'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Ayşe', 'last': 'Sadıklar'},
#    'location': {'street': {'number': 4346, 'name': 'Talak Göktepe Cd'},
#     'city': 'Giresun',
#     'state': 'Artvin',
#     'country': 'Turkey',
#     'postcode': 87174,
#     'coordinates': {'latitude': '-16.5602', 'longitude': '166.6276'},
#     'timezone': {'offset': '+2:00',
#      'description': 'Kaliningrad, South Africa'}},
#    'email': 'ayse.sadiklar@example.com',
#    'login': {'uuid': 'e62b6383-41fb-436e-b78d-0d6627e3e6dc',
#     'username': 'crazylion824',
#     'password': 'thedog',
#     'salt': 'j7U72vk3',
#     'md5': '94be10f9311044a900e517c160fdfec2',
#     'sha1': '9d882cc8605ead00cc30b8661b28e389b05cb405',
#     'sha256': '79ff138ff2cd278f15ed84d8de96ff789655dbff7cdc9f4de6b262545e949054'},
#    'dob': {'date': '1960-10-27T14:53:32.418Z', 'age': 63},
#    'registered': {'date': '2017-08-01T19:34:09.036Z', 'age': 7},
#    'phone': '(744)-736-4841',
#    'cell': '(867)-045-0246',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/20.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/20.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/20.jpg'},
#    'nat': 'TR'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'María del Carmen', 'last': 'Jimínez'},
#    'location': {'street': {'number': 7804,
#      'name': 'Ampliación Coahuila de Zaragoza'},
#     'city': 'Tlaxcoapan',
#     'state': 'Chihuahua',
#     'country': 'Mexico',
#     'postcode': 53427,
#     'coordinates': {'latitude': '40.3946', 'longitude': '-175.4612'},
#     'timezone': {'offset': '+9:30', 'description': 'Adelaide, Darwin'}},
#    'email': 'mariadelcarmen.jiminez@example.com',
#    'login': {'uuid': '531549c3-cf99-4e1b-8777-0dbd7e088552',
#     'username': 'blackpeacock967',
#     'password': 'hhhhh',
#     'salt': 'oiWnDRAz',
#     'md5': '2534d7a84a80bf918e1ed0c86df4583a',
#     'sha1': '24730f2d37646ef74ddb900bc2a2c295fa3761a0',
#     'sha256': '5794fd87d795cd6cd721a50f7e6414c4ad188a320e16b94be596195aa062fea3'},
#    'dob': {'date': '1948-08-28T03:56:29.245Z', 'age': 76},
#    'registered': {'date': '2015-12-31T06:54:13.465Z', 'age': 8},
#    'phone': '(690) 771 5181',
#    'cell': '(612) 931 3803',
#    'id': {'name': 'NSS', 'value': '33 86 31 1932 8'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/22.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/22.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/22.jpg'},
#    'nat': 'MX'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Rebecca', 'last': 'Hale'},
#    'location': {'street': {'number': 665, 'name': 'Cork Street'},
#     'city': 'Edenderry',
#     'state': 'Mayo',
#     'country': 'Ireland',
#     'postcode': 99505,
#     'coordinates': {'latitude': '12.8160', 'longitude': '-157.5085'},
#     'timezone': {'offset': '-8:00',
#      'description': 'Pacific Time (US & Canada)'}},
#    'email': 'rebecca.hale@example.com',
#    'login': {'uuid': '64d710b2-9828-4b9b-8a79-b7ea01091b28',
#     'username': 'redfish706',
#     'password': 'darthvad',
#     'salt': 'aryrC3Kw',
#     'md5': '4566d7b0fe52cc6cb06f694142ed32fb',
#     'sha1': '9682d24ffe5430d2ede21343abb5554e809840ec',
#     'sha256': '7b25e2ab91f9ddd75953f4b5269ff24fae29e284b8edc94aee4980f202613ec5'},
#    'dob': {'date': '1957-02-26T14:59:31.223Z', 'age': 67},
#    'registered': {'date': '2007-01-07T22:11:30.138Z', 'age': 17},
#    'phone': '051-977-0687',
#    'cell': '081-299-7525',
#    'id': {'name': 'PPS', 'value': '2762730T'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/14.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/14.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/14.jpg'},
#    'nat': 'IE'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Yuvraj', 'last': 'Dhamdhame'},
#    'location': {'street': {'number': 5664, 'name': 'Janpath'},
#     'city': 'Mahbubnagar',
#     'state': 'Chhattisgarh',
#     'country': 'India',
#     'postcode': 31312,
#     'coordinates': {'latitude': '19.2827', 'longitude': '103.1412'},
#     'timezone': {'offset': '0:00',
#      'description': 'Western Europe Time, London, Lisbon, Casablanca'}},
#    'email': 'yuvraj.dhamdhame@example.com',
#    'login': {'uuid': 'c6a42031-65c8-483b-8ccc-ead72cb14b5c',
#     'username': 'ticklishswan978',
#     'password': 'stalin',
#     'salt': 'BjIHy5lA',
#     'md5': '3028e7386aae2567ed8df92a91566ae7',
#     'sha1': '8c0d00aa1e959509f71c7889c298ff44fd289c78',
#     'sha256': '1ece2502f8feac8d517581d5722bab8655c324de2aed5053b3e443bd63b22e84'},
#    'dob': {'date': '1977-08-10T06:10:45.424Z', 'age': 47},
#    'registered': {'date': '2017-10-14T23:56:45.032Z', 'age': 6},
#    'phone': '7075413299',
#    'cell': '9317768302',
#    'id': {'name': 'UIDAI', 'value': '766627534126'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/40.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/40.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/40.jpg'},
#    'nat': 'IN'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Federico', 'last': 'Villanueva'},
#    'location': {'street': {'number': 9518, 'name': 'Viaducto Hidalgo'},
#     'city': 'Cruz Grande',
#     'state': 'Puebla',
#     'country': 'Mexico',
#     'postcode': 79213,
#     'coordinates': {'latitude': '3.8831', 'longitude': '-107.6343'},
#     'timezone': {'offset': '+3:00',
#      'description': 'Baghdad, Riyadh, Moscow, St. Petersburg'}},
#    'email': 'federico.villanueva@example.com',
#    'login': {'uuid': '7178b342-642c-4c86-9a75-c9ed70e56303',
#     'username': 'happymeercat407',
#     'password': 'porkchop',
#     'salt': 'h9m3rbrf',
#     'md5': '2492a2d4ab42e88902e6adffd0cde69a',
#     'sha1': 'a73174aa9f2fc34c20b9c2402e4e90e39f0a3b3b',
#     'sha256': '8cf3f3a519f35f0314508da9f0ccc9944a3b58ef17c1f06daa68e7f17183975d'},
#    'dob': {'date': '1971-11-26T12:31:22.593Z', 'age': 52},
#    'registered': {'date': '2005-04-13T18:42:41.340Z', 'age': 19},
#    'phone': '(696) 098 2615',
#    'cell': '(616) 220 8195',
#    'id': {'name': 'NSS', 'value': '80 97 33 0200 5'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/17.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/17.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/17.jpg'},
#    'nat': 'MX'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Revun', 'last': 'Beregoviy'},
#    'location': {'street': {'number': 6277, 'name': 'Mlinna'},
#     'city': 'Chudniv',
#     'state': 'Avtonomna Respublika Krim',
#     'country': 'Ukraine',
#     'postcode': 90700,
#     'coordinates': {'latitude': '62.7821', 'longitude': '56.0265'},
#     'timezone': {'offset': '0:00',
#      'description': 'Western Europe Time, London, Lisbon, Casablanca'}},
#    'email': 'revun.beregoviy@example.com',
#    'login': {'uuid': 'e683544b-6a00-4849-8544-33cac324e7a6',
#     'username': 'goldenkoala501',
#     'password': 'penguins',
#     'salt': 'iBkdlQ0z',
#     'md5': 'fe260d7f5937aceaf0aa60c1c0dd259c',
#     'sha1': '5fb6fff6dd7f1cad777a91eebc3de92fb689bc56',
#     'sha256': 'dc77d6d17a67bde19f29fdd34232e23c380336ef4712b0b5f845a41a73e1a670'},
#    'dob': {'date': '1988-10-07T16:09:42.543Z', 'age': 35},
#    'registered': {'date': '2018-03-24T17:09:45.167Z', 'age': 6},
#    'phone': '(097) Q66-5463',
#    'cell': '(098) Z19-1243',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/91.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/91.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/91.jpg'},
#    'nat': 'UA'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Harrison', 'last': 'Hughes'},
#    'location': {'street': {'number': 8880, 'name': 'Hilton Highway'},
#     'city': 'Auckland',
#     'state': 'West Coast',
#     'country': 'New Zealand',
#     'postcode': 85004,
#     'coordinates': {'latitude': '27.3304', 'longitude': '14.7586'},
#     'timezone': {'offset': '+11:00',
#      'description': 'Magadan, Solomon Islands, New Caledonia'}},
#    'email': 'harrison.hughes@example.com',
#    'login': {'uuid': '40e10ea1-06f7-41d3-ada7-ea99e342537f',
#     'username': 'orangebear889',
#     'password': 'galant',
#     'salt': 'K5OfjBhj',
#     'md5': 'd14cf66f4f2ec85647e4c9075bcda35d',
#     'sha1': '1e2e0af0e45bf10b05166f7ec0fbc13541253cf8',
#     'sha256': '0928a335314b25146c5032266bfd64cfc1ba46cacb2e0ff9319884c662b004bc'},
#    'dob': {'date': '1981-12-11T13:25:03.969Z', 'age': 42},
#    'registered': {'date': '2013-12-02T01:55:29.822Z', 'age': 10},
#    'phone': '(379)-005-3770',
#    'cell': '(871)-320-3063',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/34.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/34.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/34.jpg'},
#    'nat': 'NZ'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Fernando', 'last': 'Walters'},
#    'location': {'street': {'number': 1997, 'name': 'Rectory Lane'},
#     'city': 'Liverpool',
#     'state': 'Leicestershire',
#     'country': 'United Kingdom',
#     'postcode': 'IZ65 6BW',
#     'coordinates': {'latitude': '43.8918', 'longitude': '-30.3736'},
#     'timezone': {'offset': '+1:00',
#      'description': 'Brussels, Copenhagen, Madrid, Paris'}},
#    'email': 'fernando.walters@example.com',
#    'login': {'uuid': '2d0b9b7f-a892-4481-bff7-06e0ab9b4af0',
#     'username': 'smallostrich442',
#     'password': 'hrfzlz',
#     'salt': 'o97f1bdF',
#     'md5': '6e20d742528a55c4cf1005af9cb27d48',
#     'sha1': '01f916ba87497dddda718dc85ec500255c0ff48c',
#     'sha256': '78b4f15709fe29e0d724641726fb196a73a908eb7a3e67067f8d6ccdb61f16f2'},
#    'dob': {'date': '1949-01-20T16:56:26.393Z', 'age': 75},
#    'registered': {'date': '2011-11-17T12:39:53.073Z', 'age': 12},
#    'phone': '01697 812921',
#    'cell': '07526 010276',
#    'id': {'name': 'NINO', 'value': 'EK 07 72 49 G'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/83.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/83.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/83.jpg'},
#    'nat': 'GB'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Tjerry', 'last': 'Wittebol'},
#    'location': {'street': {'number': 301, 'name': 'Broodkist'},
#     'city': 'Papenhoven',
#     'state': 'Friesland',
#     'country': 'Netherlands',
#     'postcode': '4785 AZ',
#     'coordinates': {'latitude': '-49.5542', 'longitude': '-26.6498'},
#     'timezone': {'offset': '+8:00',
#      'description': 'Beijing, Perth, Singapore, Hong Kong'}},
# ...
#     'timezone': {'offset': '-5:00',
#      'description': 'Eastern Time (US & Canada), Bogota, Lima'}},
#    'email': 'sue.stephens@example.com',
#    'login': {'uuid': 'c2e1ebe8-5ede-4e91-b780-5ff468d117a6',
#     'username': 'crazyladybug142',
#     'password': 'alive',
#     'salt': 'N6ZOjeEA',
#     'md5': '19548c68e8eb249bdcc14f3ee6313dcb',
#     'sha1': '27bdd3c964f806d9ad74ee1200412fa6b3dd03db',
#     'sha256': 'b26f0225176fd8bafefaac8012e1c633e83d81d4f594fab355312e8e929c53b7'},
#    'dob': {'date': '1960-07-18T10:39:42.942Z', 'age': 64},
#    'registered': {'date': '2011-04-02T23:10:54.262Z', 'age': 13},
#    'phone': '(877) 369-8721',
#    'cell': '(341) 567-3289',
#    'id': {'name': 'SSN', 'value': '318-94-8942'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/93.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/93.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/93.jpg'},
#    'nat': 'US'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Rosie', 'last': 'Ward'},
#    'location': {'street': {'number': 7746, 'name': 'Grafton Street'},
#     'city': 'Athenry',
#     'state': 'Donegal',
#     'country': 'Ireland',
#     'postcode': 59940,
#     'coordinates': {'latitude': '-4.9115', 'longitude': '94.2783'},
#     'timezone': {'offset': '+6:00', 'description': 'Almaty, Dhaka, Colombo'}},
#    'email': 'rosie.ward@example.com',
#    'login': {'uuid': '5c816f1c-abc6-4478-b3ec-d3e2a0564e22',
#     'username': 'orangefish464',
#     'password': 'skylar',
#     'salt': 'ttenixRl',
#     'md5': '3025178ffb77c26225fe7d911809cee0',
#     'sha1': 'c107b3cbb6e4d59b974b99807b899cbb8f5c03bf',
#     'sha256': 'f33e897213e303d25f2712969012875b89d3fbee8072cb856333217e2e9f6c87'},
#    'dob': {'date': '2001-05-13T12:19:01.112Z', 'age': 23},
#    'registered': {'date': '2012-06-12T14:32:25.188Z', 'age': 12},
#    'phone': '051-788-3685',
#    'cell': '081-570-0309',
#    'id': {'name': 'PPS', 'value': '7232289T'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/76.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/76.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/76.jpg'},
#    'nat': 'IE'},
#   {'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Concetta', 'last': 'Mühl'},
#    'location': {'street': {'number': 9559, 'name': 'Kirchgasse'},
#     'city': 'Nittenau',
#     'state': 'Bayern',
#     'country': 'Germany',
#     'postcode': 79146,
#     'coordinates': {'latitude': '-8.6598', 'longitude': '-76.8533'},
#     'timezone': {'offset': '+11:00',
#      'description': 'Magadan, Solomon Islands, New Caledonia'}},
#    'email': 'concetta.muhl@example.com',
#    'login': {'uuid': 'fac501da-0aba-4b72-a695-fcc97cc67710',
#     'username': 'beautifulpanda137',
#     'password': 'chocha',
#     'salt': '6yMMZFpH',
#     'md5': '2c935cc408e27edac27eb29f44803a43',
#     'sha1': 'cf16e29abcd2b36ea06ae1a03e9b84be0530edac',
#     'sha256': '03af798a771a27a4c0ec48cdd9ce5c7c8cfbb600e013c56fea950584bf775cda'},
#    'dob': {'date': '1993-12-21T00:12:42.172Z', 'age': 30},
#    'registered': {'date': '2008-06-09T23:38:26.390Z', 'age': 16},
#    'phone': '0492-8461394',
#    'cell': '0178-9923229',
#    'id': {'name': 'SVNR', 'value': '17 201293 M 664'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/78.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/78.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/78.jpg'},
#    'nat': 'DE'},
#   {'gender': 'female',
#    'name': {'title': 'Mrs', 'first': 'Alicia', 'last': 'Parra'},
#    'location': {'street': {'number': 9666, 'name': 'Calle de Ferraz'},
#     'city': 'Logroño',
#     'state': 'País Vasco',
#     'country': 'Spain',
#     'postcode': 14943,
#     'coordinates': {'latitude': '75.9024', 'longitude': '-167.3192'},
#     'timezone': {'offset': '-9:00', 'description': 'Alaska'}},
#    'email': 'alicia.parra@example.com',
#    'login': {'uuid': 'f67a477f-7241-43c1-b7aa-a792063f3361',
#     'username': 'happysnake694',
#     'password': 'babies',
#     'salt': 'xEhAllXV',
#     'md5': '59a9aae6391f78e597881c764163c364',
#     'sha1': '0df34c26262e5b8f6bbcd66b0ecb896bafc85bad',
#     'sha256': '30f82773bb64615718e3c9c05c416e7ee090181e027cfe0ba296632677227652'},
#    'dob': {'date': '1948-03-05T12:09:54.044Z', 'age': 76},
#    'registered': {'date': '2019-12-08T07:22:06.637Z', 'age': 4},
#    'phone': '977-662-175',
#    'cell': '663-348-129',
#    'id': {'name': 'DNI', 'value': '32927860-O'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/50.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/50.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/50.jpg'},
#    'nat': 'ES'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Claude', 'last': 'Shelton'},
#    'location': {'street': {'number': 1081, 'name': 'York Road'},
#     'city': 'Lusk',
#     'state': 'Waterford',
#     'country': 'Ireland',
#     'postcode': 87466,
#     'coordinates': {'latitude': '80.4282', 'longitude': '-67.4841'},
#     'timezone': {'offset': '-11:00', 'description': 'Midway Island, Samoa'}},
#    'email': 'claude.shelton@example.com',
#    'login': {'uuid': '41991e83-873e-41f8-a9e4-a716ad27fa85',
#     'username': 'lazyleopard551',
#     'password': 'yamaha',
#     'salt': 'fIUs0Zcz',
#     'md5': '22615ec2d7a5bcd271dd7cadc87dfaa2',
#     'sha1': '51084704d648e65ac1e95d8e2e9075fec21dfbab',
#     'sha256': 'e612762dbe7f5c3b8f87a8790d3df6567d73764b52dd346104d31dfc7f4b9e8a'},
#    'dob': {'date': '1980-12-26T13:42:40.347Z', 'age': 43},
#    'registered': {'date': '2019-11-11T04:51:03.577Z', 'age': 4},
#    'phone': '011-970-2222',
#    'cell': '081-938-2817',
#    'id': {'name': 'PPS', 'value': '5545338T'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/55.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/55.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/55.jpg'},
#    'nat': 'IE'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Nolan', 'last': 'Bourgeois'},
#    'location': {'street': {'number': 4325, 'name': 'Rue Barrier'},
#     'city': 'Courbevoie',
#     'state': 'Eure-et-Loir',
#     'country': 'France',
#     'postcode': 42094,
#     'coordinates': {'latitude': '-83.2857', 'longitude': '-9.1215'},
#     'timezone': {'offset': '+8:00',
#      'description': 'Beijing, Perth, Singapore, Hong Kong'}},
#    'email': 'nolan.bourgeois@example.com',
#    'login': {'uuid': 'fda6ef51-7bde-4b14-8a8b-c3777832f5df',
#     'username': 'purplelion922',
#     'password': 'face',
#     'salt': 'qNxcEqxA',
#     'md5': 'a06f1dacb849b8b6dffd9808cd1836b8',
#     'sha1': '54b1b400a40428ec8fa9037d1dbc0f7976182314',
#     'sha256': 'a7a20ac525b2a46cea5381cea4a608b1b07d997760ae47763eb9e6865678ef79'},
#    'dob': {'date': '1972-08-09T00:14:34.065Z', 'age': 52},
#    'registered': {'date': '2014-04-13T22:43:00.679Z', 'age': 10},
#    'phone': '03-15-81-33-25',
#    'cell': '06-52-84-22-00',
#    'id': {'name': 'INSEE', 'value': '1720780342973 19'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/62.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/62.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/62.jpg'},
#    'nat': 'FR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'آرش', 'last': 'یاسمی'},
#    'location': {'street': {'number': 8887, 'name': 'پاتریس لومومبا'},
#     'city': 'گرگان',
#     'state': 'گیلان',
#     'country': 'Iran',
#     'postcode': 27494,
#     'coordinates': {'latitude': '27.8842', 'longitude': '156.2724'},
#     'timezone': {'offset': '+10:00',
#      'description': 'Eastern Australia, Guam, Vladivostok'}},
#    'email': 'arsh.ysmy@example.com',
#    'login': {'uuid': 'ea39d92b-5688-475e-9865-bab8b6b25acd',
#     'username': 'silvermeercat456',
#     'password': 'walter',
#     'salt': '05JqyQQJ',
#     'md5': '179b568861c19cd22bcaa67658f9c29c',
#     'sha1': 'fa3580e89ed2f6e1bc4071f2c80fb0f3410de15a',
#     'sha256': '8e25f51adfbd5ffb8bde79baafb8e6ea8fc8fd242143f056bce351936d330723'},
#    'dob': {'date': '1962-06-19T02:14:02.421Z', 'age': 62},
#    'registered': {'date': '2007-10-01T23:06:10.305Z', 'age': 16},
#    'phone': '023-60073840',
#    'cell': '0923-059-3512',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/62.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/62.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/62.jpg'},
#    'nat': 'IR'},
#   {'gender': 'female',
#    'name': {'title': 'Ms', 'first': 'Mina', 'last': 'Teodosić'},
#    'location': {'street': {'number': 9574, 'name': 'Marte Jorgović '},
#     'city': 'Mitrovica',
#     'state': 'Jablanica',
#     'country': 'Serbia',
#     'postcode': 14449,
#     'coordinates': {'latitude': '-21.2516', 'longitude': '50.8126'},
#     'timezone': {'offset': '-3:30', 'description': 'Newfoundland'}},
#    'email': 'mina.teodosic@example.com',
#    'login': {'uuid': '138e9f45-7c51-405a-a844-9a4db326bdca',
#     'username': 'ticklishmeercat725',
#     'password': 'lonely',
#     'salt': 'a2veY3vh',
#     'md5': 'b3d9507198ec295e651635ef127fa278',
#     'sha1': '7a17086b341a90d12165b28bfc3c39fef13798b6',
#     'sha256': 'e7b810313df410967bded58021a28dae4774d197f141a0bd3f37b417ba80d490'},
#    'dob': {'date': '1995-08-22T03:51:17.010Z', 'age': 29},
#    'registered': {'date': '2006-09-01T01:08:03.589Z', 'age': 18},
#    'phone': '033-2745-933',
#    'cell': '061-4887-116',
#    'id': {'name': 'SID', 'value': '195761040'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/91.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/91.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/91.jpg'},
#    'nat': 'RS'},
#   {'gender': 'female',
#    'name': {'title': 'Ms', 'first': 'Aldonza', 'last': 'Mateo'},
#    'location': {'street': {'number': 6027, 'name': 'Circuito Tabasco'},
#     'city': 'Telixtac',
#     'state': 'Sonora',
#     'country': 'Mexico',
#     'postcode': 72726,
#     'coordinates': {'latitude': '-27.3544', 'longitude': '108.2790'},
#     'timezone': {'offset': '-5:00',
#      'description': 'Eastern Time (US & Canada), Bogota, Lima'}},
#    'email': 'aldonza.mateo@example.com',
#    'login': {'uuid': 'a762266b-a6fb-41e2-9b1c-f17129e764e1',
#     'username': 'organicrabbit150',
#     'password': 'volkswag',
#     'salt': '6JCkH4SN',
#     'md5': '73edc40136dc017a19654101cbcbc6bb',
#     'sha1': '27ef9d72065df02a239b2af01d8250ebfc7778fc',
#     'sha256': '08d2fe1c4fbc23e8310d016457736da7ee8274efe8d1853e70feb80e5ed369f4'},
#    'dob': {'date': '1986-06-27T07:12:31.457Z', 'age': 38},
#    'registered': {'date': '2007-08-19T01:11:24.175Z', 'age': 17},
#    'phone': '(680) 047 8314',
#    'cell': '(688) 981 3876',
#    'id': {'name': 'NSS', 'value': '69 55 40 5096 0'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/26.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/26.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/26.jpg'},
#    'nat': 'MX'},
#   {'gender': 'female',
#    'name': {'title': 'Ms', 'first': 'Elizabeth', 'last': 'Stewart'},
#    'location': {'street': {'number': 477, 'name': 'High Street'},
#     'city': 'Ennis',
#     'state': 'Wicklow',
#     'country': 'Ireland',
#     'postcode': 15050,
#     'coordinates': {'latitude': '-39.9795', 'longitude': '52.6028'},
#     'timezone': {'offset': '+9:30', 'description': 'Adelaide, Darwin'}},
#    'email': 'elizabeth.stewart@example.com',
#    'login': {'uuid': '24302b38-e976-403f-8ed9-e9f12d8cac2f',
#     'username': 'greengoose930',
#     'password': 'derf',
#     'salt': 'h5L4Ire4',
#     'md5': 'e8888e923c0c0122df77ab7520668e3c',
#     'sha1': '18f4ebabd8b68897ff22add71ea6b156fbd7fac3',
#     'sha256': '910a6bd4948ba5e4e6e5d5b0ae4933c067cbc1ef744c9597f6bd63a8916b950d'},
#    'dob': {'date': '1982-05-20T11:34:56.671Z', 'age': 42},
#    'registered': {'date': '2006-11-24T09:00:06.911Z', 'age': 17},
#    'phone': '041-151-8629',
#    'cell': '081-769-3011',
#    'id': {'name': 'PPS', 'value': '0987993T'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/women/95.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/women/95.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/95.jpg'},
#    'nat': 'IE'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Fatih', 'last': 'Orbay'},
#    'location': {'street': {'number': 2861, 'name': 'Talak Göktepe Cd'},
#     'city': 'Ordu',
#     'state': 'Trabzon',
#     'country': 'Turkey',
#     'postcode': 73044,
#     'coordinates': {'latitude': '12.5694', 'longitude': '74.8286'},
#     'timezone': {'offset': '-4:00',
#      'description': 'Atlantic Time (Canada), Caracas, La Paz'}},
#    'email': 'fatih.orbay@example.com',
#    'login': {'uuid': 'b182116a-469d-4f28-bd07-eb81e2f36a8b',
#     'username': 'happyrabbit536',
#     'password': 'roll',
#     'salt': 'bEAtSJzq',
#     'md5': 'e2d6ba220fa120e36b4a971163514629',
#     'sha1': '0ec0304aae5bbdf17ae63c121b723f52c88b9c6a',
#     'sha256': 'cbe11f4a3cab7aaad542da72d9456f9b25b4c5ca12ad8c0c42b1d1cf4849d255'},
#    'dob': {'date': '1968-04-19T20:02:22.949Z', 'age': 56},
#    'registered': {'date': '2010-01-21T00:37:55.337Z', 'age': 14},
#    'phone': '(117)-208-1568',
#    'cell': '(585)-135-5405',
#    'id': {'name': '', 'value': None},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/26.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/26.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/26.jpg'},
#    'nat': 'TR'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Dawid', 'last': 'Evju'},
#    'location': {'street': {'number': 2633, 'name': 'Nordahl Bruns gate'},
#     'city': 'Liknes',
#     'state': 'Description',
#     'country': 'Norway',
#     'postcode': '0665',
#     'coordinates': {'latitude': '26.5219', 'longitude': '160.6827'},
#     'timezone': {'offset': '-9:00', 'description': 'Alaska'}},
#    'email': 'dawid.evju@example.com',
#    'login': {'uuid': 'ae885faf-13a4-4a6a-867a-2dcff6fc58db',
#     'username': 'bluepanda223',
#     'password': 'fireman',
#     'salt': 'mdf39xqG',
#     'md5': '1e6f654a34389838b48ac8036f493ab9',
#     'sha1': '9a22eb48906cbd1864795460913d59919918bbe1',
#     'sha256': '95260cb14a1c660988ebd1cde166fa3124721c0619ab40c506c347c267d70163'},
#    'dob': {'date': '1946-07-01T14:58:52.588Z', 'age': 78},
#    'registered': {'date': '2012-10-30T08:00:20.131Z', 'age': 11},
#    'phone': '84938347',
#    'cell': '92638147',
#    'id': {'name': 'FN', 'value': '01074622387'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/88.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/88.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/88.jpg'},
#    'nat': 'NO'},
#   {'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Mike', 'last': 'Deininger'},
#    'location': {'street': {'number': 5375, 'name': 'Schützenstraße'},
#     'city': 'Kölleda',
#     'state': 'Bayern',
#     'country': 'Germany',
#     'postcode': 94437,
#     'coordinates': {'latitude': '-47.1526', 'longitude': '-158.5018'},
#     'timezone': {'offset': '-12:00', 'description': 'Eniwetok, Kwajalein'}},
#    'email': 'mike.deininger@example.com',
#    'login': {'uuid': '61ff9937-7536-449c-b618-be310b53c7e2',
#     'username': 'angryzebra210',
#     'password': 'pertinant',
#     'salt': 'LotkqehC',
#     'md5': '1ee27751c03eeb708b216093321be6a9',
#     'sha1': 'a342f6ef44e5446f4bda37020222d1c7f65f3754',
#     'sha256': '132a2d1380e75227428854c1fe0d3e62e633b5e8dc0c1bacd9eebf573a66bec8'},
#    'dob': {'date': '1962-07-17T23:25:54.780Z', 'age': 62},
#    'registered': {'date': '2006-08-29T19:58:20.752Z', 'age': 18},
#    'phone': '0884-2022786',
#    'cell': '0174-1675376',
#    'id': {'name': 'SVNR', 'value': '63 170762 D 115'},
#    'picture': {'large': 'https://randomuser.me/api/portraits/men/55.jpg',
#     'medium': 'https://randomuser.me/api/portraits/med/men/55.jpg',
#     'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/55.jpg'},
#    'nat': 'DE'}],
#  'info': {'seed': 'eaa8df8036b8a0d8',
#   'results': 100,
#   'page': 1,
#   'version': '1.4'}}

# %%
df = pd.json_normalize(data) # decoding the json

# %%
df
# Out:
#                                              results         info.seed  \
# 0  [{'gender': 'male', 'name': {'title': 'Mr', 'f...  eaa8df8036b8a0d8
#
#    info.results  info.page info.version
# 0           100          1          1.4

# %%
for i in df['results']: # looking over each record within results column, it is nested json
    print(i)
# Out:
# [{'gender': 'male', 'name': {'title': 'Mr', 'first': 'Jordan', 'last': 'Cooper'}, 'location': {'street': {'number': 5968, 'name': 'Pine Hill Road'}, 'city': 'Upper Hutt', 'state': 'Canterbury', 'country': 'New Zealand', 'postcode': 73563, 'coordinates': {'latitude': '53.4953', 'longitude': '-9.3661'}, 'timezone': {'offset': '+11:00', 'description': 'Magadan, Solomon Islands, New Caledonia'}}, 'email': 'jordan.cooper@example.com', 'login': {'uuid': '91f9ad2b-b2c7-4b77-ad2e-fa4d2fab5faf', 'username': 'blacktiger984', 'password': 'sites', 'salt': 'UhWDUBD3', 'md5': '970c50a6eda12eef6e2d39a49c62dd25', 'sha1': '6f8e50b1d965b54bf0f57f72baed2fb3efe0c529', 'sha256': '0b4a8e998e4457e10422e32cb9542a732bf5ce2a15e85e590ada4c093e7c85e7'}, 'dob': {'date': '1981-08-30T08:11:44.967Z', 'age': 43}, 'registered': {'date': '2008-03-05T03:44:24.166Z', 'age': 16}, 'phone': '(196)-739-6917', 'cell': '(230)-965-5933', 'id': {'name': '', 'value': None}, 'picture': {'large': 'https://randomuser.me/api/portraits/men/82.jpg', 'medium': 'https://randomuser.me/api/portraits/med/men/82.jpg', 'thumbnail': 'https://randomuser.me/api/portraits/thumb/men/82.jpg'}, 'nat': 'NZ'}, {'gender': 'female', 'name': {'title': 'Miss', 'first': 'Alejandra', 'last': 'Navarro'}, 'location': {'street': {'number': 9821, 'name': 'Avenida del Planetario'}, 'city': 'Zaragoza', 'state': 'Región de Murcia', 'country': 'Spain', 'postcode': 58896, 'coordinates': {'latitude': '-65.2840', 'longitude': '102.2584'}, 'timezone': {'offset': '-1:00', 'description': 'Azores, Cape Verde Islands'}}, 'email': 'alejandra.navarro@example.com', 'login': {'uuid': '450fa88f-455d-40a2-af3f-f82125b26d71', 'username': 'beautifulduck872', 'password': 'jazz', 'salt': 'lhjuRlx2', 'md5': '5ad2feb769a820b289a25c6301fa17fb', 'sha1': 'ea1f2d8b61a42c0dfa39a5c0e71e894a25ffc634', 'sha256': '91f7afe81be516be50b91c3b7f9a0192d09ab27461088312a16ad0bfdd14ed4f'}, 'dob': {'date': '1974-02-10T23:07:05.446Z', 'age': 50}, 'registered': {'date': '2011-03-24T04:15:01.456Z', 'age': 13}, 'phone': '944-647-997', 'cell': '616-064-054', 'id': {'name': 'DNI', 'value': '34351659-U'}, 'picture': {'large': 'https://randomuser.me/api/portraits/women/48.jpg', 'medium': 'https://randomuser.me/api/portraits/med/women/48.jpg', 'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/48.jpg'}, 'nat': 'ES'}, {'gender': 'female', 'name': {'title': 'Miss', 'first': 'Stacy', 'last': 'Johnston'}, 'location': {'street': {'number': 6811, 'name': 'Saddle Dr'}, 'city': 'Tulsa', 'state': 'Iowa', 'country': 'United States', 'postcode': 58733, 'coordinates': {'latitude': '-52.1532', 'longitude': '129.0020'}, 'timezone': {'offset': '-9:00', 'description': 'Alaska'}}, 'email': 'stacy.johnston@example.com', 'login': {'uuid': '87877a6b-ffb2-490a-b097-4759298ecfbe', 'username': 'organiccat893', 'password': 'shemale', 'salt': 'UqJhKLnI', 'md5': '3113f6a953d46a7496600a60ec83e129', 'sha1': 'db37592ebeb5589f96c4b7f128f3a0c59d1f91e5', 'sha256': 'd64f78c01f72bd1501a8745f160d036f29b42c161c4653f109be0a32e354a01d'}, 'dob': {'date': '1986-03-14T02:23:35.113Z', 'age': 38}, 'registered': {'date': '2009-09-14T09:48:23.699Z', 'age': 15}, 'phone': '(898) 334-0030', 'cell': '(330) 502-0955', 'id': {'name': 'SSN', 'value': '016-64-0103'}, 'picture': {'large': 'https://randomuser.me/api/portraits/women/73.jpg', 'medium': 'https://randomuser.me/api/portraits/med/women/73.jpg', 'thumbnail': 'https://randomuser.me/api/portraits/thumb/women/73.jpg'}, 'nat': 'US'}, {'gender': 'male', 'name': {'title': 'Mr', 'first': 'John', 'last': 'Matthews'}, 'location': {'street': {'number': 2863, 'name': 'The Crescent'}, 'city': 'Kilcoole', 'state': 'South Dublin', 'country': 'Ireland', 'postcode': 95591, 'coordinates': {'latitude': '-5.0675', 'longitude': '-63.5333'}, 'timezone': {'offset': '-3:30', 'description': 'Newfoundland'}}, 'email': 'john.matthews@example.com', 'login': {'uuid': '1abe48c4-9199-438c-91eb-5ccfd2560041', 'username': 'redzebra849', 'password': 'green1', 'salt': 'u ...

# %%
# Create lists to store the extracted user data
first_name_ls = []
last_name_ls = []
emails_ls = []
genders_ls = []
countries_ls = []
age_ls = []

# %%
# Loop through each user and extract relevant details
for user in data['results']:
    
    email = user.get('email', np.nan) # if no value is present then it will impute None there
    emails_ls.append(email)
    
    first_name = user['name'].get('first', np.nan)
    first_name_ls.append(first_name)
    
    last_name = user['name'].get('last', np.nan)
    last_name_ls.append(last_name)
    
    gender = user.get('gender', np.nan)
    genders_ls.append(gender)
    
    country = user['location'].get('country', np.nan)
    countries_ls.append(country)
    
    age = user['dob'].get('age', np.nan)
    age_ls.append(age)

# %%
df = pd.DataFrame({
    'first_name': first_name_ls,
     'last_name': last_name_ls,
     'Email': emails_ls,
     'Gender': genders_ls,
     'Country': countries_ls,
     'age': age_ls
})

# %%
df.head()
# Out:
#      first_name     last_name                              Email  Gender  \
# 0      Brigitte          Dost          brigitte.dost@example.com  female
# 1       Luk'yan  Kozachinskiy   luk'yan.kozachinskiy@example.com    male
# 2  Anne-Kathrin      Zitzmann  anne-kathrin.zitzmann@example.com  female
# 3        Marlon  Van de Kleut      marlon.vandekleut@example.com  female
# 4      Scarlett        Harper        scarlett.harper@example.com  female
#
#           Country  age
# 0         Germany   67
# 1         Ukraine   77
# 2         Germany   24
# 3     Netherlands   54
# 4  United Kingdom   73

# %% [markdown]
# ## Load

# %% [markdown]
# create a schema and empty table in sql database before this step:
#
# ```create schema users;```
#
# ```
# create table users.user_details
# (
#
# first_name varchar(500),
# last_name varchar(500),
# Email varchar(500),
# Gender varchar(100),
# Country varchar(500),
# age varchar(100)
# )
# ```

# %%
import mysql.connector
mydb= mysql.connector.connect(host='localhost',user='root',passwd='sawan', database = 'users')

# %%
cursordb= mydb.cursor()

# %%
for index, row in df.iterrows(): # it will fetch one row at a time
    
    sql_query = "insert into user_details (first_name,last_name,Email,Gender,Country,age) values (%s,%s,%s,%s,%s,%s)"
    cursordb.execute(sql_query, (row['first_name'],row['last_name'],row['Email'],row['Gender'],row['Country'],row['age']))
print("data loaded successfully")
# Out:
# data loaded successfully

# %% [markdown]
# ### Create stored procedure in sql to clean the data

# %% [markdown]
# ```
# DELIMITER //
# -- Provide name to procedure
# CREATE PROCEDURE users.user_data_transformation ()
# BEGIN
# drop table if exists users.user_transformed;
# create table users.user_transformed
# SELECT first_name, last_name, email,
#  SUBSTRING(email, LOCATE('@', email) + 1) AS hostname,
#  gender, country,
# case when age<=18 then 'below 18'
# when age>18 and age<=35 then '18-35'
# when age>35 and age<=65 then '35-65'
# when age>=65 then 'above 65'
# else 'below 18'
# end as age_bucket
#   FROM   users.user_details;
# END //
# DELIMITER ;
# ```

# %%
# calling stored procedure
cursordb.callproc('user_data_transformation')
# Out:
# ()

# %%
mydb.commit() # your changes will be reflected after commit
mydb.close()

# %% [markdown]
# ## now use vscode to create .py file

# %% [markdown]
# **step 1** empty the tables,  truncate the users table and drop the output table of stored procedure
# <br>**step 2** copy the same code in vscode, also add print and time sleep
# <br> **step 3** open the cmd
# <br> **step 4** change directory to D if required using command
# ```D:```
# <br> **step 5** change location cd Documents\DAS\KRPRO_Python\24012024\Projects\ETL
# <br> **step 6** using ```dir``` you can see contents in folder
# <br> **step 7** please install the python and respective libraries, pandas for eg: ```pip install requests```
# <br> **step 8** now run the script using python api_script.py
